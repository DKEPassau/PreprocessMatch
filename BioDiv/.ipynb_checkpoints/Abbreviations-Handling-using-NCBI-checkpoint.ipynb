# %%
import pandas as pd
import gzip
import json
import matplotlib.pyplot as plt
import os
import seaborn as sns
import langid

# %%
# Read all tables and store them in dfs list
dfs = {}
tables_path = "Dataset/val/tables/"
files = os.listdir(tables_path)
for file in files:
    df = pd.read_csv(tables_path + file)
    dfs[file] = df

# %%
new_column_names = ['Table Name', 'Column Index', 'Row Index', 'Retrieved Annotation']
df_output = pd.read_csv("Dataset/output/cea annotation/cea_biodiv_first_experiment.csv", header=None, names=new_column_names)
df_output.head()
# Out:
#                          Table Name  Column Index  Row Index  \
# 0  008851b16aa04124b3a9195676604f35             0          0
# 1  008851b16aa04124b3a9195676604f35             0          1
# 2  008851b16aa04124b3a9195676604f35             0          2
# 3  008851b16aa04124b3a9195676604f35             0          3
# 4  008851b16aa04124b3a9195676604f35             0          4
#
#                      Retrieved Annotation
# 0     https://www.wikidata.org/wiki/Q7432
# 1  https://www.wikidata.org/wiki/Q2093287
# 2  https://www.wikidata.org/wiki/Q8261255
# 3  https://www.wikidata.org/wiki/Q2942992
# 4  https://www.wikidata.org/wiki/Q1105092

# %%
# Retrieve all rows with NaN values in a specific column
nan_rows = df_output[df_output["Retrieved Annotation"].isnull()]

# Print the resulting dataframe
print(nan_rows)
# Out:
#                             Table Name  Column Index  Row Index  \
# 58    008851b16aa04124b3a9195676604f35             2         89
# 59    008851b16aa04124b3a9195676604f35             2         91
# 75    008851b16aa04124b3a9195676604f35            10          0
# 76    008851b16aa04124b3a9195676604f35            11          0
# 86    008851b16aa04124b3a9195676604f35            25          1
# ...                                ...           ...        ...
# 2004  e749786aff714981a5a7da3da0789128             1         95
# 2005  e749786aff714981a5a7da3da0789128             1         96
# 2006  e749786aff714981a5a7da3da0789128             1         97
# 2007  e749786aff714981a5a7da3da0789128             1         98
# 2008  e749786aff714981a5a7da3da0789128             1         99
#
#      Retrieved Annotation
# 58                    NaN
# 59                    NaN
# 75                    NaN
# 76                    NaN
# 86                    NaN
# ...                   ...
# 2004                  NaN
# 2005                  NaN
# 2006                  NaN
# 2007                  NaN
# 2008                  NaN
#
# [1246 rows x 4 columns]

# %%
# Mapping with the value
new_column_names = ['Table Name', 'Column Index', 'Row Index', 'Target Annotation']
cea_gt = pd.read_csv(f"Dataset/val/gt/CEA_biodivtab_selected_tables_gt.csv", header=None, names=new_column_names)
values = {}
for index, row in nan_rows.iterrows():
    # Load the dataframe
    df = pd.read_csv(f"Dataset/val/tables/{row[0]}.csv", header=None)
    annotation = cea_gt[(cea_gt.iloc[:,0] == row[0]) & (cea_gt.iloc[:,1] == row[1]) & (cea_gt.iloc[:,2] == row[2])].iloc[:,3].values[0]
    cell_value = df.iloc[row[2], row[1]]
    values[cell_value] = annotation

# %%
# join prediction and target dataframes
merged_df = pd.merge(cea_gt, df_output, on=['Table Name', 'Column Index', 'Row Index'])

# %%
# Add Cell Content
def retrieve_cell_value(row):
    df = pd.read_csv(f"Dataset/val/tables/{row['Table Name']}.csv", header=None)
    cell_value = df.iloc[row["Row Index"], row["Column Index"]]
    return cell_value
    
merged_df["Cell Value"] = merged_df.apply(lambda row: retrieve_cell_value(row), axis=1)

# %%
# Correct retrieval
nan_values = merged_df[(merged_df["Target Annotation"] != merged_df["Retrieved Annotation"]) & 
                       (merged_df["Retrieved Annotation"].isna())]

# %%
# Count number of nan_values strings with abbreviations
def detect_abbreviation_in_string(row):
    if row["Cell Value"].count(".") == 1 and row["Cell Value"].count("*") == 0 and row["Cell Value"][0].isupper():
        return True
    return False

# Apply the lambda function to identify True values
mask = nan_values[["Cell Value", "Target Annotation"]].apply(lambda row: detect_abbreviation_in_string(row), axis=1)

# Use the mask to filter and store the values that returned True
abbreviation_values = nan_values.loc[mask, :]
abbreviation_values
# Out:
#                             Table Name  Column Index  Row Index  \
# 997   34169c088ee848e4866f42e87b4ccbc2             5          1
# 998   34169c088ee848e4866f42e87b4ccbc2             5          5
# 999   34169c088ee848e4866f42e87b4ccbc2             5         11
# 1000  34169c088ee848e4866f42e87b4ccbc2             5         20
# 1001  34169c088ee848e4866f42e87b4ccbc2             5         27
# ...                                ...           ...        ...
# 1431  8249f8533f764f6dbd195a872c18fd6d             0         86
# 1432  8249f8533f764f6dbd195a872c18fd6d             0         87
# 1433  8249f8533f764f6dbd195a872c18fd6d             0         88
# 1434  8249f8533f764f6dbd195a872c18fd6d             0         90
# 1435  8249f8533f764f6dbd195a872c18fd6d             0         91
#
#                             Target Annotation Retrieved Annotation  \
# 997   https://www.wikidata.org/wiki/Q15340551                  NaN
# 998   https://www.wikidata.org/wiki/Q12838227                  NaN
# 999   https://www.wikidata.org/wiki/Q15490427                  NaN
# 1000    https://www.wikidata.org/wiki/Q847209                  NaN
# 1001  https://www.wikidata.org/wiki/Q15247814                  NaN
# ...                                       ...                  ...
# 1431    https://www.wikidata.org/wiki/Q610177                  NaN
# 1432   https://www.wikidata.org/wiki/Q3766704                  NaN
# 1433    https://www.wikidata.org/wiki/Q606436                  NaN
# 1434   https://www.wikidata.org/wiki/Q6406968                  NaN
# 1435    https://www.wikidata.org/wiki/Q723654                  NaN
#
#           Cell Value
# 997    D.glaucifolia
# 998         C.glauca
# 999         L.glaber
# 1000       Q.serrata
# 1001  C.sclerophylla
# ...              ...
# 1431      C.cognatus
# 1432    C.spiloptera
# 1433      E.olmstedi
# 1434    H.roanokense
# 1435    S.fontinalis
#
# [92 rows x 6 columns]

# %%
abbreviations = abbreviation_values["Cell Value"].values.tolist()
abbreviations
# Out:
# ['D.glaucifolia',
#  'C.glauca',
#  'L.glaber',
#  'Q.serrata',
#  'C.sclerophylla',
#  'L.formosana',
#  'R.chinensis',
#  'C.fargesii',
#  'Ca. eyrei',
#  'Ch. axillaris',
#  'Ac. davidii',
#  'Li. formosana',
#  'Ci. camphora',
#  'Tr. cochinchinensis',
#  'Sc. superba',
#  'Ca. henryi',
#  'Cy. glauca',
#  'Di. japonica',
#  'Da. oldhamii',
#  'Di. myricoides',
#  'Pi. massoniana',
#  'Ca. fargesii',
#  'Ma. thunbergii',
#  'It. chinensis',
#  'Ko. bipinnata',
#  'Cy. myrsinifolia',
#  'Ca. carlesii',
#  'Qu. serrata',
#  'Rh. indica',
#  'Sa. saponaria',
#  'Ny. sinensis',
#  'Qu. fabri',
#  'Qu. acutissima',
#  'Li. glaber',
#  'Rh. chinensis',
#  'El. japonicus',
#  'Al. fortunei',
#  'El. chinensis',
#  'Ma. fordiana',
#  'Tr. sebifera',
#  'Me. flexuosa',
#  'Ma. grijsii',
#  'Me. azedarach',
#  'Qu. phillyreoides',
#  'Cu. lanceolata',
#  'Ca. sclerophylla',
#  'A.rupestris',
#  'C.anomalum',
#  'C.commersonii',
#  'C.erythrogaster',
#  'C.funduloides',
#  'E.caeruleum',
#  'N.buccatus',
#  'P.notatus',
#  'R.obtusus',
#  'S.atromaculatus',
#  'E.blennioides',
#  'E.flabellare',
#  'C.cumberlandensis',
#  'E.kennicotti',
#  'E.nigrum',
#  'L.auritus',
#  'L.macrochirus',
#  'R.atratulus',
#  'M.punctulatus',
#  'M.erythrurum',
#  'N.leuciodus',
#  'N.photogenis',
#  'N.miurus',
#  'L.aepyptera',
#  'L.megalotis',
#  'L.chrysocephalus',
#  'N.rubellus',
#  'P.caprodes',
#  'S.vitreus',
#  'A.natalis',
#  'N.micropogon',
#  'E.zonale',
#  'I.bubalus',
#  'L.cyanellus',
#  'C.bairdii',
#  'C.carpio',
#  'E.niger',
#  'R.cataractae',
#  'L.cornutus',
#  'S.trutta',
#  'S.corporalis',
#  'C.cognatus',
#  'C.spiloptera',
#  'E.olmstedi',
#  'H.roanokense',
#  'S.fontinalis']

# %%
import requests
import xml.etree.ElementTree as ET


def make_get_request(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses

        # Parse the XML content
        xml_content = response.content
        root = ET.fromstring(xml_content)

        # Now 'root' contains the XML content, and you can navigate and extract information as needed.

        return root

    except requests.exceptions.RequestException as e:
        print(f"Error during GET request: {e}")
        return None


def retrieve_full_name(abbreviation):
    print(abbreviation)
    abb = abbreviation.split(".")[0]
    word = abbreviation.split(".")[-1].strip()
    
    # Example URL
    url = f"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=taxonomy&term={word}[Name%20Tokens]&retmax=1000"  

    # Make the GET request
    result_xml = make_get_request(url)

    # Example: Extract information from the XML response
    if result_xml is not None:
        # Assume the XML structure, adapt based on your actual XML content
        ids = []
        for child in result_xml:
            if child.tag == "IdList":
                for ids_list_child in child:
                    ids.append(ids_list_child.text)                
                    
    possible_full_strings = []
    for id in ids:
        url = f"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id={id}&version=2.0" 
        while True:
            try:
                result_xml = make_get_request(url)
                string = result_xml.find(".//ScientificName").text
                if (string.split(" ")[0][0] == abb[0] and len(string.split(" ")) == 2):
                    possible_full_strings.append(string) 
                break
            except:
                continue
    return possible_full_strings

# %%
full_strings = {}
for abbreviation in abbreviations:
    possible_full_strings = retrieve_full_name(abbreviation)
    full_strings[abbreviation] = possible_full_strings
# Out:
# D.glaucifolia
# C.glauca
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=2789716&version=2.0
# L.glaber
# Q.serrata
# C.sclerophylla
# L.formosana
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=1559352&version=2.0
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=1008966&version=2.0
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=1008966&version=2.0
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=1008966&version=2.0
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=886264&version=2.0
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=886264&version=2.0
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=886264&version=2.0
# R.chinensis
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=1232631&version=2.0
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=1232631&version=2.0
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=328260&version=2.0
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=236202&version=2.0
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=232576&version=2.0
# C.fargesii
# Ca. eyrei
# Ch. axillaris
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=722558&version=2.0
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=505190&version=2.0
# Error during GET request: HTTPSConnectionPool(host='eutils.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /entrez/eutils/esummary.fcgi?db=taxonomy&id=504180&version=2.0 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DAAEA74048>: Failed to establish a new connection: [WinError 10060] Une tentative de connexion a échoué car le parti connecté n’a pas répondu convenablement au-delà d’une certaine durée ou une connexion établie a échoué car l’hôte de connexion n’a pas répondu',))
# Ac. davidii
# Li. formosana
# Ci. camphora
# Tr. cochinchinensis
# Sc. superba
# Ca. henryi
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=1621235&version=2.0
# Cy. glauca
# Di. japonica
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=2761443&version=2.0
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=2758704&version=2.0
# Error during GET request: 502 Server Error: Bad Gateway for url: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=taxonomy&id=2603858&version=2.0
# Da. oldhamii
# Di. myricoides
# Pi. massoniana
# Ca. fargesii
# Ma. thunbergii
# It. chinensis
# Ko. bipinnata
# Cy. myrsinifolia
# Ca. carlesii
# Qu. serrata
# Error during GET request: ('Connection aborted.', OSError("(10054, 'WSAECONNRESET')",))
# Rh. indica
# Sa. saponaria
# Ny. sinensis
# Qu. fabri
# Qu. acutissima
# Li. glaber
# Rh. chinensis
# El. japonicus
# Al. fortunei
# El. chinensis
# Ma. fordiana
# Tr. sebifera
# Me. flexuosa
# From cffi callback <function _verify_callback at 0x000001DAAEB136A8>:
# Traceback (most recent call last):
#   File "C:\Users\lenovo\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 311, in wrapper
#     @wraps(callback)
# KeyboardInterrupt
# Error during GET request: HTTPSConnectionPool(host='eutils.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /entrez/eutils/esummary.fcgi?db=taxonomy&id=584955&version=2.0 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')],)",),))
# Ma. grijsii
# Me. azedarach
# From cffi callback <function _verify_callback at 0x000001DAAEB13400>:
# Traceback (most recent call last):
#   File "C:\Users\lenovo\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 311, in wrapper
#     @wraps(callback)
# KeyboardInterrupt
# Error during GET request: HTTPSConnectionPool(host='eutils.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /entrez/eutils/esummary.fcgi?db=taxonomy&id=1848402&version=2.0 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')],)",),))
# Qu. phillyreoides
# Cu. lanceolata
# From cffi callback <function _verify_callback at 0x000001DAAEB13D08>:
# Traceback (most recent call last):
#   File "C:\Users\lenovo\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 311, in wrapper
#     @wraps(callback)
# KeyboardInterrupt
# Error during GET request: HTTPSConnectionPool(host='eutils.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /entrez/eutils/esummary.fcgi?db=taxonomy&id=3089904&version=2.0 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')],)",),))
# From cffi callback <function _verify_callback at 0x000001DAAEB1EA60>:
# Traceback (most recent call last):
#   File "C:\Users\lenovo\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 311, in wrapper
#     @wraps(callback)
# KeyboardInterrupt
# Error during GET request: HTTPSConnectionPool(host='eutils.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /entrez/eutils/esummary.fcgi?db=taxonomy&id=2488027&version=2.0 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')],)",),))
# From cffi callback <function _verify_callback at 0x000001DAAEB13158>:
# Traceback (most recent call last):
#   File "C:\Users\lenovo\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 311, in wrapper
#     @wraps(callback)
# KeyboardInterrupt
# Error during GET request: HTTPSConnectionPool(host='eutils.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /entrez/eutils/esummary.fcgi?db=taxonomy&id=659965&version=2.0 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')],)",),))
# Ca. sclerophylla
# A.rupestris
# C.anomalum
# C.commersonii
# C.erythrogaster
# C.funduloides
# E.caeruleum
# N.buccatus
# P.notatus
# R.obtusus
# S.atromaculatus
# E.blennioides
# E.flabellare
# C.cumberlandensis
# E.kennicotti
# E.nigrum
# L.auritus
# L.macrochirus
# R.atratulus
# M.punctulatus
# M.erythrurum
# N.leuciodus
# N.photogenis
# N.miurus
# L.aepyptera
# L.megalotis
# L.chrysocephalus
# N.rubellus
# P.caprodes
# S.vitreus
# A.natalis
# N.micropogon
# E.zonale
# I.bubalus
# L.cyanellus
# C.bairdii
# C.carpio
# E.niger
# R.cataractae
# L.cornutus
# S.trutta
# S.corporalis
# C.cognatus
# C.spiloptera
# E.olmstedi
# H.roanokense
# S.fontinalis

# %%
full_strings
# Out:
# {'D.glaucifolia': ['Diospyros glaucifolia'],
#  'C.glauca': ['Causonis glauca',
#   'Cyanosporus glauca',
#   'Caloncoba glauca',
#   'Clematis glauca',
#   'Cheilanthes glauca',
#   'Caeruleuptychia glauca',
#   'Cycas glauca',
#   'Chlorociboria glauca',
#   'Chusquea glauca',
#   'Cassine glauca',
#   'Crotalaria glauca',
#   'Choleva glauca',
#   'Callitris glauca',
#   'Carinavalva glauca',
#   'Cliffortia glauca',
#   'Cyathea glauca',
#   'Cardamine glauca',
#   'Cleistopholis glauca',
#   'Calceolaria glauca',
#   'Chrysiptera glauca',
#   'Cheniella glauca',
#   'Cladonia glauca',
#   'Canna glauca',
#   'Chrysochlamys glauca',
#   'Cyrtostachys glauca',
#   'Cissus repens',
#   'Craspedia glauca',
#   'Citrus glauca',
#   'Cyathodes glauca',
#   'Centropodia glauca',
#   'Cenchrus americanus',
#   'Casuarina glauca',
#   'Capnoides sempervirens'],
#  'L.glaber': ['Leiaster glaber', 'Lotus tenuis', 'Lithocarpus glaber'],
#  'Q.serrata': ['Quercus serrata'],
#  'C.sclerophylla': ['Calamagrostis sclerophylla',
#   'Campanula sclerophylla',
#   'Cousinia sclerophylla',
#   'Castanopsis sclerophylla',
#   'Cryptocarya sclerophylla'],
#  'L.formosana': ['Lichtwardtia formosana',
#   'Lozotaeniodes formosana',
#   'Liparopsis formosana',
#   'Lactuca formosana',
#   'Lychnuris formosana',
#   'Liparis formosana',
#   'Loligo formosana',
#   'Lithocarpus formosanus',
#   'Liquidambar formosana'],
#  'R.chinensis': ['Roussoella chinensis',
#   'Rhizochaete chinensis',
#   'Rungia chinensis',
#   'Rubia chinensis',
#   'Riparia chinensis',
#   'Rohdea chinensis',
#   'Ranatra chinensis',
#   'Rhynchospora chinensis',
#   'Ranunculus chinensis',
#   'Rhus chinensis',
#   'Rhabdothamnopsis sinensis',
#   'Reticulitermes chinensis',
#   'Rosa chinensis'],
#  'C.fargesii': ['Corydalis fargesii',
#   'Carex fargesii',
#   'Clethra fargesii',
#   'Cypripedium fargesii',
#   'Corylus fargesii',
#   'Chengiopanax fargesii',
#   'Castanopsis fargesii',
#   'Catalpa fargesii'],
#  'Ca. eyrei': ['Castanopsis eyrei'],
#  'Ch. axillaris': ['Cyclocodon axillaris',
#   'Calamus axillaris',
#   'Chartocerus axillaris',
#   'Cymindis axillaris',
#   'Cyanotis axillaris',
#   'Cavendishia axillaris',
#   'Canephora axillaris',
#   'Chionanthus axillaris',
#   'Campanula axillaris',
#   'Crotalaria axillaris',
#   'Coptosperma supra-axillare',
#   'Cyathelia axillaris',
#   'Croton axillaris',
#   'Caesulia axillaris',
#   'Choerospondias axillaris',
#   'Camarea axillaris',
#   'Caloglossa axillaris',
#   'Clusiella axillaris',
#   'Coursetia axillaris'],
#  'Ac. davidii': ['Alchornea davidii',
#   'Adonis davidii',
#   'Anemone davidii',
#   'Adiantum davidii',
#   'Abraximorpha davidii',
#   'Acer davidii'],
#  'Li. formosana': ['Lichtwardtia formosana',
#   'Lozotaeniodes formosana',
#   'Liparopsis formosana',
#   'Lactuca formosana',
#   'Lychnuris formosana',
#   'Liparis formosana',
#   'Loligo formosana',
#   'Lithocarpus formosanus',
#   'Liquidambar formosana'],
#  'Ci. camphora': ['Cinnamomum camphora'],
#  'Tr. cochinchinensis': ['Trapa cochinchinensis',
#   'Turpinia cochinchinensis',
#   'Triadica cochinchinensis'],
#  'Sc. superba': ['Spiraea brumalis',
#   'Siproeta superba',
#   'Sphaerostephanos superbus',
#   'Sarada superba',
#   'Selaginella superba',
#   'Superba reischuetzi',
#   'Shorea superba',
#   'Stephanophyes superba',
#   'Sordaria superba',
#   'Saussurea superba',
#   'Semanga superba',
#   'Scutellinia superba',
#   'Schima superba'],
#  'Ca. henryi': ['Clerodendrum henryi',
#   'Campylotropis henryi',
#   'Carex henryi',
#   'Chrysosplenium henryi',
#   'Codonopsis henryi',
#   'Caryodaphnopsis henryi',
#   'Culicoides henryi',
#   'Calanthe henryi',
#   'Clematis henryi',
#   'Cypripedium henryi',
#   'Cirsium henryi',
#   'Corymbia henryi',
#   'Castanea henryi',
#   'Chloranthus henryi'],
#  'Cy. glauca': ['Causonis glauca',
#   'Cyanosporus glauca',
#   'Caloncoba glauca',
#   'Clematis glauca',
#   'Cheilanthes glauca',
#   'Caeruleuptychia glauca',
#   'Cycas glauca',
#   'Chlorociboria glauca',
#   'Chusquea glauca',
#   'Cassine glauca',
#   'Crotalaria glauca',
#   'Choleva glauca',
#   'Callitris glauca',
#   'Carinavalva glauca',
#   'Cliffortia glauca',
#   'Cyathea glauca',
#   'Cardamine glauca',
#   'Cleistopholis glauca',
#   'Calceolaria glauca',
#   'Chrysiptera glauca',
#   'Cheniella glauca',
#   'Cladonia glauca',
#   'Canna glauca',
#   'Chrysochlamys glauca',
#   'Cyrtostachys glauca',
#   'Cissus repens',
#   'Craspedia glauca',
#   'Citrus glauca',
#   'Cyathodes glauca',
#   'Centropodia glauca',
#   'Cenchrus americanus',
#   'Casuarina glauca',
#   'Capnoides sempervirens'],
#  'Di. japonica': ['Doto japonica',
#   'Delomerista japonica',
#   'Diospyros japonica',
#   'Docosia japonica',
#   'Diplolepis japonica',
#   'Diatrypella japonica',
#   'Diestrammena japanica',
#   'Dasysiphonia japonica',
#   'Desis japonica',
#   'Dusona japonica',
#   'Dacryomaia japonica',
#   'Dolophilodes japonica',
#   'Drymonia japonica',
#   'Doclea japonica',
#   'Diophrys japonica',
#   'Desmarestia japonica',
#   'Diamesa japonica',
#   'Doryrhamphus japonicus',
#   'Diplectrona japonica',
#   'Discodermia japonica',
#   'Ducetia japonica',
#   'Drawida japonica',
#   'Draba japonica',
#   'Dosinia japonica',
#   'Dyella japonica',
#   'Dimya japonica',
#   'Deparia japonica'],
#  'Da. oldhamii': ['Diospyros oldhamii', 'Daphniphyllum oldhamii'],
#  'Di. myricoides': ['Ditta myricoides', 'Distylium myricoides'],
#  'Pi. massoniana': ['Pinus massoniana'],
#  'Ca. fargesii': ['Corydalis fargesii',
#   'Carex fargesii',
#   'Clethra fargesii',
#   'Cypripedium fargesii',
#   'Corylus fargesii',
#   'Chengiopanax fargesii',
#   'Castanopsis fargesii',
#   'Catalpa fargesii'],
#  'Ma. thunbergii': ['Machilus pauhoi',
#   'Machilus japonica',
#   'Muraltia thunbergii',
#   'Machilus thunbergii'],
#  'It. chinensis': ['Isara chinensis',
#   'Ips chinensis',
#   'Ilex chinensis',
#   'Itea chinensis',
#   'Itea omeiensis',
#   'Ixora chinensis',
#   'Ixeris chinensis',
#   'Ixonanthes chinensis',
#   'Impatiens chinensis',
#   'Iris domestica'],
#  'Ko. bipinnata': ['Koelreuteria bipinnata'],
#  'Cy. myrsinifolia': [],
#  'Ca. carlesii': ['Castanopsis carlesii'],
#  'Qu. serrata': ['Quercus serrata'],
#  'Rh. indica': ['Raclitia indica',
#   'Raillietiella indica',
#   'Rhabderemia indica',
#   'Rosa indica',
#   'Radionaspis indica',
#   'Rothia indica',
#   'Rhodocybe indica',
#   'Ratufa indica',
#   'Rickenella indica',
#   'Raoiella indica',
#   'Rhaphiolepis umbellata',
#   'Rotala indica',
#   'Rosa cymosa',
#   'Rhododendron indicum',
#   'Rosa chinensis',
#   'Rorippa indica',
#   'Rhaphiolepis indica',
#   'Reinwardtia indica'],
#  'Sa. saponaria': ['Saponaria makranica',
#   'Saponaria pumilio',
#   'Saponaria zapaterii',
#   'Saponaria subrosularis',
#   'Saponaria stenopetala',
#   'Saponaria prostrata',
#   'Saponaria pinetorum',
#   'Saponaria pamphylica',
#   'Saponaria orientalis',
#   'Saponaria mesogitana',
#   'Saponaria kotschyi',
#   'Saponaria kermanensis',
#   'Saponaria intricata',
#   'Saponaria intermedia',
#   'Saponaria haussknechtii',
#   'Saponaria griffithiana',
#   'Saponaria floribunda',
#   'Saponaria cypria',
#   'Saponaria chlorifolia',
#   'Saponaria cerastoides',
#   'Saponaria caespitosa',
#   'Saponaria bodeana',
#   'Saponaria bellidifolia',
#   'Saponaria atocioides',
#   'Saponaria lutea',
#   'Saponaria glutinosa',
#   'Saponaria pumila',
#   'Sapindus saponaria',
#   'Saponaria sicula',
#   'Saponaria ocymoides',
#   'Saponaria calabrica',
#   'Saponaria officinalis'],
#  'Ny. sinensis': ['Neohydnus sinensis',
#   'Neopseustis sinensis',
#   'Novopuccinia sycopsis-sinensis',
#   'Nicrophorus sinensis',
#   'Nigrospora camelliae-sinensis',
#   'Neodatronia sinensis',
#   'Nesticoccus sinensis',
#   'Nemausa sinensis',
#   'Nasoonaria sinensis',
#   'Neoconidiobolus sinensis',
#   'Nosekiella sinensis',
#   'Neotetracus sinensis',
#   'Neolycaena sinensis',
#   'Nyssa sinensis',
#   'Neochauliodes sinensis',
#   'Neriene sinensis',
#   'Nectria sinensis',
#   'Neillia sinensis'],
#  'Qu. fabri': ['Quercus fabri'],
#  'Qu. acutissima': ['Quercus acutissima'],
#  'Li. glaber': ['Leiaster glaber', 'Lotus tenuis', 'Lithocarpus glaber'],
#  'Rh. chinensis': ['Roussoella chinensis',
#   'Rhizochaete chinensis',
#   'Rungia chinensis',
#   'Rubia chinensis',
#   'Riparia chinensis',
#   'Rohdea chinensis',
#   'Ranatra chinensis',
#   'Rhynchospora chinensis',
#   'Ranunculus chinensis',
#   'Rhus chinensis',
#   'Rhabdothamnopsis sinensis',
#   'Reticulitermes chinensis',
#   'Rosa chinensis'],
#  'El. japonicus': ['Ephies japonicus',
#   'Echiniscus japonicus',
#   'Epinephelus japonicus',
#   'Eudectus japonicus',
#   'Eupalamus japonicus',
#   'Euscyrtus japonicus',
#   'Eurytetranychoides japonicus',
#   'Echinochasmus japonicus',
#   'Eusphingonotus japonicus',
#   'Elaeocarpus japonicus',
#   'Eodiaptomus japonicus',
#   'Eurypogon japonicus',
#   'Euchiton japonicus',
#   'Eleutherococcus japonicus',
#   'Euonymus japonicus',
#   'Esastigmatobius japonicus',
#   'Eriocheir japonica',
#   'Epiactis japonica',
#   'Elenchus japonicus',
#   'Engraulis japonicus'],
#  'Al. fortunei': ['Ambrostoma fortunei',
#   'Apios fortunei',
#   'Amata fortunei',
#   'Aglaomorpha fortunei',
#   'Alniphyllum fortunei'],
#  'El. chinensis': ['Estigmena chinensis',
#   'Excalfactoria adansonii',
#   'Endothia chinensis',
#   'Eobia chinensis',
#   'Ellobium chinense',
#   'Enithares chinensis',
#   'Eucryptorrhynchus scrobiculatus',
#   'Euops chinensis',
#   'Euagathis chinensis',
#   'Eothenomys wardi',
#   'Eophileurus chinensis',
#   'Elaeocarpus chinensis',
#   'Epicauta chinensis',
#   'Eremurus chinensis',
#   'Eothenomys chinensis',
#   'Epilachna chinensis',
#   'Eptatretus chinensis',
#   'Enkianthus chinensis',
#   'Eurya chinensis',
#   'Eriocheir sinensis',
#   'Excalfactoria chinensis'],
#  'Ma. fordiana': ['Meliphaga fordiana', 'Magnolia fordiana'],
#  'Tr. sebifera': ['Triadica sebifera'],
#  'Me. flexuosa': ['Miltochrista flexuosa',
#   'Menonvillea flexuosa',
#   'Macrozamia flexuosa',
#   'Meliosma flexuosa',
#   'Muhlenbergia flexuosa',
#   'Muhlenbergia multiflora',
#   'Marantochloa flexuosa',
#   'Malcolmia flexuosa',
#   'Mylabris flexuosa',
#   'Marilia flexuosa',
#   'Mauritia flexuosa'],
#  'Ma. grijsii': ['Machilus grijsii'],
#  'Me. azedarach': ['Melia azedarach'],
#  'Qu. phillyreoides': [],
#  'Cu. lanceolata': ['Cleocnemis lanceolata',
#   'Cerastium lanceolatum',
#   'Coelioxys lanceolata',
#   'Coniogramme lanceolata',
#   'Catasticta lanceolata',
#   'Campanula lanceolata',
#   'Cyathula lanceolata',
#   'Ctenitis lanceolata',
#   'Crudia lanceolata',
#   'Claytonia peirsonii',
#   'Chroesthes lanceolata',
#   'Chassalia lanceolata',
#   'Cylindrifflugia lanceolata',
#   'Cylindrocladiella lanceolata',
#   'Cassipourea lanceolata',
#   'Cyanostegia lanceolata',
#   'Calceolaria lanceolata',
#   'Cakile lanceolata',
#   'Cliffortia lanceolata',
#   'Cunninghamia unicanaliculata',
#   'Cephalotaxus lanceolata',
#   'Calyptranthes lanceolata',
#   'Caridina lanceolata',
#   'Claytonia lanceolata',
#   'Chiroxiphia lanceolata',
#   'Camellia lanceolata',
#   'Clusia lanceolata',
#   'Crotalaria lanceolata',
#   'Coreopsis lanceolata',
#   'Canastra lanceolata',
#   'Cotylelobium lanceolatum',
#   'Carex lanceolata',
#   'Codonopsis lanceolata',
#   'Curvibacter lanceolatus',
#   'Crepidiastrum lanceolatum',
#   'Cunninghamia lanceolata',
#   'Callistachys lanceolata',
#   'Cuphea lanceolata'],
#  'Ca. sclerophylla': ['Calamagrostis sclerophylla',
#   'Campanula sclerophylla',
#   'Cousinia sclerophylla',
#   'Castanopsis sclerophylla',
#   'Cryptocarya sclerophylla'],
#  'A.rupestris': ['Aspalathus rupestris',
#   'Agastache rupestris',
#   'Aedes rupestris',
#   'Acanthocarpus rupestris',
#   'Asterolasia rupestris',
#   'Argyrolobium rupestre',
#   'Arundinella rupestris',
#   'Astyanax rupestris',
#   'Asperula rupestris',
#   'Acanthocyclops signifer',
#   'Agrostis rupestris',
#   'Alstroemeria rupestris',
#   'Aloe rupestris',
#   'Amphorocalyx rupestris',
#   'Anthyllis rupestris',
#   'Albuca rupestris',
#   'Anemone rupestris',
#   'Alchemilla rupestris',
#   'Argocoffeopsis rupestris',
#   'Anthracoidea rupestris',
#   'Aosa rupestris',
#   'Adenodolichos rupestris',
#   'Aleisanthia rupestris',
#   'Ambloplites rupestris',
#   'Artemisia rupestris',
#   'Atocion rupestre',
#   'Andreaea rupestris'],
#  'C.anomalum': ['Chlamydomyzium anomalum',
#   'Cardiospermum anomalum',
#   'Campostoma plumbeum',
#   'Campostoma oligolepis',
#   'Campostoma pullum',
#   'Chaetostoma anomalum',
#   'Campostoma anomalum'],
#  'C.commersonii': ['Commicarpus commersonii',
#   'Cephalorhynchus commersonii',
#   'Cylindrocline commersonii',
#   'Catostomus commersonii'],
#  'C.erythrogaster': ['Cephalcia erythrogaster',
#   'Cercopithecus erythrogaster',
#   'Caesio cuning',
#   'Chrosomus erythrogaster'],
#  'C.funduloides': ['Clinostomus funduloides'],
#  'E.caeruleum': ['Entoloma caeruleum',
#   'Exacum caeruleum',
#   'Eryngium caeruleum',
#   'Etheostoma caeruleum'],
#  'N.buccatus': [],
#  'P.notatus': ['Polyipnus notatus',
#   'Platypalpus notatus',
#   'Petaurus notatus',
#   'Peromatus notatus',
#   'Philorhizus notatus',
#   'Platycheirus notatus',
#   'Platynematichthys notatus',
#   'Paraxanthias notatus',
#   'Polemon notatus',
#   'Pissodes notatus',
#   'Pimephales notatus',
#   'Porichthys notatus'],
#  'R.obtusus': ['Rhinichthys obtusus'],
#  'S.atromaculatus': ['Squalidus atromaculatus', 'Semotilus atromaculatus'],
#  'E.blennioides': ['Etheostoma newmanii',
#   'Etheostoma pholidotum',
#   'Etheostoma blennioides'],
#  'E.flabellare': ['Etheostoma humerale', 'Etheostoma flabellare'],
#  'C.cumberlandensis': ['Cambarus cumberlandensis',
#   'Carex cumberlandensis',
#   'Chrosomus cumberlandensis'],
#  'E.kennicotti': ['Etheostoma kennicotti'],
#  'E.nigrum': ['Emoia nigra',
#   'Eiphosoma nigrum',
#   'Empetrum nigrum',
#   'Epicoccum nigrum',
#   'Etheostoma nigrum'],
#  'L.auritus': ['Lepomis auritus',
#   'Lethrinops auritus',
#   'Limnochromis auritus'],
#  'L.macrochirus': ['Lepomis macrochirus'],
#  'R.atratulus': ['Rhinichthys atratulus'],
#  'M.punctulatus': ['Melanoplus punctulatus',
#   'Micropterus henshalli',
#   'Micropterus punctulatus',
#   'Mustelus punctulatus'],
#  'M.erythrurum': ['Moxostoma erythrurum'],
#  'N.leuciodus': ['Notropis leuciodus'],
#  'N.photogenis': ['Notropis scabriceps',
#   'Notropis leuciodus',
#   'Notropis telescopus',
#   'Notropis photogenis',
#   'Notropis ariommus'],
#  'N.miurus': ['Noturus miurus'],
#  'L.aepyptera': ['Lampetra aepyptera'],
#  'L.megalotis': ['Lepomis megalotis'],
#  'L.chrysocephalus': ['Luxilus chrysocephalus'],
#  'N.rubellus': ['Notropis rubellus'],
#  'P.caprodes': ['Percina fulvitaenia', 'Percina burtoni', 'Percina caprodes'],
#  'S.vitreus': ['Syrphoctonus vitreus', 'Sander vitreus'],
#  'A.natalis': ['Amyna natalis', 'Ameiurus natalis'],
#  'N.micropogon': ['Nocomis micropogon'],
#  'E.zonale': ['Etheostoma zonale'],
#  'I.bubalus': ['Ictiobus bubalus'],
#  'L.cyanellus': ['Lepomis cyanellus'],
#  'C.bairdii': ['Centronyx bairdii',
#   'Calliostoma bairdii',
#   'Cryptosoma bairdii',
#   'Calidris bairdii',
#   'Cottus bairdii'],
#  'C.carpio': ['Cyprinus megalophthalmus',
#   'Cyprinus chilia',
#   'Carassioides cantonensis',
#   'Carpiodes carpio',
#   'Cyprinus carpio'],
#  'E.niger': ['Eschatocerus niger',
#   'Ectreposebastes niger',
#   'Epyris niger',
#   'Enoplochiton niger',
#   'Echthrus niger',
#   'Eniclases niger',
#   'Emoia nigra',
#   'Eudactylinodes niger',
#   'Eantis niger',
#   'Epipona niger',
#   'Esox niger',
#   'Eresus cinnaberinus',
#   'Ephedrus niger'],
#  'R.cataractae': ['Rhinichthys cataractae'],
#  'L.cornutus': ['Lithurgus cornutus',
#   'Lissotes cornutus',
#   'Lactoria cornuta',
#   'Larinioides cornutus',
#   'Luxilus cerasinus',
#   'Luxilus cornutus'],
#  'S.trutta': ['Salmo abanticus',
#   'Salmo pellegrini',
#   'Salmo macedonicus',
#   'Salmo labrax',
#   'Salmo caspius',
#   'Salmo letnica',
#   'Symphodus trutta',
#   'Salmo macrostigma',
#   'Salmo marmoratus',
#   'Salmo trutta'],
#  'S.corporalis': ['Semotilus corporalis'],
#  'C.cognatus': ['Cardiophorus cognatus',
#   'Chorthippus fallax',
#   'Corydalus cornutus',
#   'Cybister cognatus',
#   'Cryptoblepharus cognatus',
#   'Cottus cognatus',
#   'Calathus cognatus'],
#  'C.spiloptera': ['Cyprinella spiloptera'],
#  'E.olmstedi': ['Etheostoma olmstedi'],
#  'H.roanokense': ['Hypentelium roanokense'],
#  'S.fontinalis': ['Sabulina fontinalis',
#   'Scirpus fontinalis',
#   'Salvelinus fontinalis']}

# %%
# Save the dictionary to a Pickle file
import pickle
with open('abbreviation_mapping.pkl', 'wb') as pickle_file:
    pickle.dump(full_strings, pickle_file)

# %%
# Load the dictionary from the Pickle file
import pickle

with open('abbreviation_mapping.pkl', 'rb') as pickle_file:
    loaded_data = pickle.load(pickle_file)
loaded_data
# Out:
# {'D.glaucifolia': ['Diospyros glaucifolia'],
#  'C.glauca': ['Causonis glauca',
#   'Cyanosporus glauca',
#   'Caloncoba glauca',
#   'Clematis glauca',
#   'Cheilanthes glauca',
#   'Caeruleuptychia glauca',
#   'Cycas glauca',
#   'Chlorociboria glauca',
#   'Chusquea glauca',
#   'Cassine glauca',
#   'Crotalaria glauca',
#   'Choleva glauca',
#   'Callitris glauca',
#   'Carinavalva glauca',
#   'Cliffortia glauca',
#   'Cyathea glauca',
#   'Cardamine glauca',
#   'Cleistopholis glauca',
#   'Calceolaria glauca',
#   'Chrysiptera glauca',
#   'Cheniella glauca',
#   'Cladonia glauca',
#   'Canna glauca',
#   'Chrysochlamys glauca',
#   'Cyrtostachys glauca',
#   'Cissus repens',
#   'Craspedia glauca',
#   'Citrus glauca',
#   'Cyathodes glauca',
#   'Centropodia glauca',
#   'Cenchrus americanus',
#   'Casuarina glauca',
#   'Capnoides sempervirens'],
#  'L.glaber': ['Leiaster glaber', 'Lotus tenuis', 'Lithocarpus glaber'],
#  'Q.serrata': ['Quercus serrata'],
#  'C.sclerophylla': ['Calamagrostis sclerophylla',
#   'Campanula sclerophylla',
#   'Cousinia sclerophylla',
#   'Castanopsis sclerophylla',
#   'Cryptocarya sclerophylla'],
#  'L.formosana': ['Lichtwardtia formosana',
#   'Lozotaeniodes formosana',
#   'Liparopsis formosana',
#   'Lactuca formosana',
#   'Lychnuris formosana',
#   'Liparis formosana',
#   'Loligo formosana',
#   'Lithocarpus formosanus',
#   'Liquidambar formosana'],
#  'R.chinensis': ['Roussoella chinensis',
#   'Rhizochaete chinensis',
#   'Rungia chinensis',
#   'Rubia chinensis',
#   'Riparia chinensis',
#   'Rohdea chinensis',
#   'Ranatra chinensis',
#   'Rhynchospora chinensis',
#   'Ranunculus chinensis',
#   'Rhus chinensis',
#   'Rhabdothamnopsis sinensis',
#   'Reticulitermes chinensis',
#   'Rosa chinensis'],
#  'C.fargesii': ['Corydalis fargesii',
#   'Carex fargesii',
#   'Clethra fargesii',
#   'Cypripedium fargesii',
#   'Corylus fargesii',
#   'Chengiopanax fargesii',
#   'Castanopsis fargesii',
#   'Catalpa fargesii'],
#  'Ca. eyrei': ['Castanopsis eyrei'],
#  'Ch. axillaris': ['Cyclocodon axillaris',
#   'Calamus axillaris',
#   'Chartocerus axillaris',
#   'Cymindis axillaris',
#   'Cyanotis axillaris',
#   'Cavendishia axillaris',
#   'Canephora axillaris',
#   'Chionanthus axillaris',
#   'Campanula axillaris',
#   'Crotalaria axillaris',
#   'Coptosperma supra-axillare',
#   'Cyathelia axillaris',
#   'Croton axillaris',
#   'Caesulia axillaris',
#   'Choerospondias axillaris',
#   'Camarea axillaris',
#   'Caloglossa axillaris',
#   'Clusiella axillaris',
#   'Coursetia axillaris'],
#  'Ac. davidii': ['Alchornea davidii',
#   'Adonis davidii',
#   'Anemone davidii',
#   'Adiantum davidii',
#   'Abraximorpha davidii',
#   'Acer davidii'],
#  'Li. formosana': ['Lichtwardtia formosana',
#   'Lozotaeniodes formosana',
#   'Liparopsis formosana',
#   'Lactuca formosana',
#   'Lychnuris formosana',
#   'Liparis formosana',
#   'Loligo formosana',
#   'Lithocarpus formosanus',
#   'Liquidambar formosana'],
#  'Ci. camphora': ['Cinnamomum camphora'],
#  'Tr. cochinchinensis': ['Trapa cochinchinensis',
#   'Turpinia cochinchinensis',
#   'Triadica cochinchinensis'],
#  'Sc. superba': ['Spiraea brumalis',
#   'Siproeta superba',
#   'Sphaerostephanos superbus',
#   'Sarada superba',
#   'Selaginella superba',
#   'Superba reischuetzi',
#   'Shorea superba',
#   'Stephanophyes superba',
#   'Sordaria superba',
#   'Saussurea superba',
#   'Semanga superba',
#   'Scutellinia superba',
#   'Schima superba'],
#  'Ca. henryi': ['Clerodendrum henryi',
#   'Campylotropis henryi',
#   'Carex henryi',
#   'Chrysosplenium henryi',
#   'Codonopsis henryi',
#   'Caryodaphnopsis henryi',
#   'Culicoides henryi',
#   'Calanthe henryi',
#   'Clematis henryi',
#   'Cypripedium henryi',
#   'Cirsium henryi',
#   'Corymbia henryi',
#   'Castanea henryi',
#   'Chloranthus henryi'],
#  'Cy. glauca': ['Causonis glauca',
#   'Cyanosporus glauca',
#   'Caloncoba glauca',
#   'Clematis glauca',
#   'Cheilanthes glauca',
#   'Caeruleuptychia glauca',
#   'Cycas glauca',
#   'Chlorociboria glauca',
#   'Chusquea glauca',
#   'Cassine glauca',
#   'Crotalaria glauca',
#   'Choleva glauca',
#   'Callitris glauca',
#   'Carinavalva glauca',
#   'Cliffortia glauca',
#   'Cyathea glauca',
#   'Cardamine glauca',
#   'Cleistopholis glauca',
#   'Calceolaria glauca',
#   'Chrysiptera glauca',
#   'Cheniella glauca',
#   'Cladonia glauca',
#   'Canna glauca',
#   'Chrysochlamys glauca',
#   'Cyrtostachys glauca',
#   'Cissus repens',
#   'Craspedia glauca',
#   'Citrus glauca',
#   'Cyathodes glauca',
#   'Centropodia glauca',
#   'Cenchrus americanus',
#   'Casuarina glauca',
#   'Capnoides sempervirens'],
#  'Di. japonica': ['Doto japonica',
#   'Delomerista japonica',
#   'Diospyros japonica',
#   'Docosia japonica',
#   'Diplolepis japonica',
#   'Diatrypella japonica',
#   'Diestrammena japanica',
#   'Dasysiphonia japonica',
#   'Desis japonica',
#   'Dusona japonica',
#   'Dacryomaia japonica',
#   'Dolophilodes japonica',
#   'Drymonia japonica',
#   'Doclea japonica',
#   'Diophrys japonica',
#   'Desmarestia japonica',
#   'Diamesa japonica',
#   'Doryrhamphus japonicus',
#   'Diplectrona japonica',
#   'Discodermia japonica',
#   'Ducetia japonica',
#   'Drawida japonica',
#   'Draba japonica',
#   'Dosinia japonica',
#   'Dyella japonica',
#   'Dimya japonica',
#   'Deparia japonica'],
#  'Da. oldhamii': ['Diospyros oldhamii', 'Daphniphyllum oldhamii'],
#  'Di. myricoides': ['Ditta myricoides', 'Distylium myricoides'],
#  'Pi. massoniana': ['Pinus massoniana'],
#  'Ca. fargesii': ['Corydalis fargesii',
#   'Carex fargesii',
#   'Clethra fargesii',
#   'Cypripedium fargesii',
#   'Corylus fargesii',
#   'Chengiopanax fargesii',
#   'Castanopsis fargesii',
#   'Catalpa fargesii'],
#  'Ma. thunbergii': ['Machilus pauhoi',
#   'Machilus japonica',
#   'Muraltia thunbergii',
#   'Machilus thunbergii'],
#  'It. chinensis': ['Isara chinensis',
#   'Ips chinensis',
#   'Ilex chinensis',
#   'Itea chinensis',
#   'Itea omeiensis',
#   'Ixora chinensis',
#   'Ixeris chinensis',
#   'Ixonanthes chinensis',
#   'Impatiens chinensis',
#   'Iris domestica'],
#  'Ko. bipinnata': ['Koelreuteria bipinnata'],
#  'Cy. myrsinifolia': [],
#  'Ca. carlesii': ['Castanopsis carlesii'],
#  'Qu. serrata': ['Quercus serrata'],
#  'Rh. indica': ['Raclitia indica',
#   'Raillietiella indica',
#   'Rhabderemia indica',
#   'Rosa indica',
#   'Radionaspis indica',
#   'Rothia indica',
#   'Rhodocybe indica',
#   'Ratufa indica',
#   'Rickenella indica',
#   'Raoiella indica',
#   'Rhaphiolepis umbellata',
#   'Rotala indica',
#   'Rosa cymosa',
#   'Rhododendron indicum',
#   'Rosa chinensis',
#   'Rorippa indica',
#   'Rhaphiolepis indica',
#   'Reinwardtia indica'],
#  'Sa. saponaria': ['Saponaria makranica',
#   'Saponaria pumilio',
#   'Saponaria zapaterii',
#   'Saponaria subrosularis',
#   'Saponaria stenopetala',
#   'Saponaria prostrata',
#   'Saponaria pinetorum',
#   'Saponaria pamphylica',
#   'Saponaria orientalis',
#   'Saponaria mesogitana',
#   'Saponaria kotschyi',
#   'Saponaria kermanensis',
#   'Saponaria intricata',
#   'Saponaria intermedia',
#   'Saponaria haussknechtii',
#   'Saponaria griffithiana',
#   'Saponaria floribunda',
#   'Saponaria cypria',
#   'Saponaria chlorifolia',
#   'Saponaria cerastoides',
#   'Saponaria caespitosa',
#   'Saponaria bodeana',
#   'Saponaria bellidifolia',
#   'Saponaria atocioides',
#   'Saponaria lutea',
#   'Saponaria glutinosa',
#   'Saponaria pumila',
#   'Sapindus saponaria',
#   'Saponaria sicula',
#   'Saponaria ocymoides',
#   'Saponaria calabrica',
#   'Saponaria officinalis'],
#  'Ny. sinensis': ['Neohydnus sinensis',
#   'Neopseustis sinensis',
#   'Novopuccinia sycopsis-sinensis',
#   'Nicrophorus sinensis',
#   'Nigrospora camelliae-sinensis',
#   'Neodatronia sinensis',
#   'Nesticoccus sinensis',
#   'Nemausa sinensis',
#   'Nasoonaria sinensis',
#   'Neoconidiobolus sinensis',
#   'Nosekiella sinensis',
#   'Neotetracus sinensis',
#   'Neolycaena sinensis',
#   'Nyssa sinensis',
#   'Neochauliodes sinensis',
#   'Neriene sinensis',
#   'Nectria sinensis',
#   'Neillia sinensis'],
#  'Qu. fabri': ['Quercus fabri'],
#  'Qu. acutissima': ['Quercus acutissima'],
#  'Li. glaber': ['Leiaster glaber', 'Lotus tenuis', 'Lithocarpus glaber'],
#  'Rh. chinensis': ['Roussoella chinensis',
#   'Rhizochaete chinensis',
#   'Rungia chinensis',
#   'Rubia chinensis',
#   'Riparia chinensis',
#   'Rohdea chinensis',
#   'Ranatra chinensis',
#   'Rhynchospora chinensis',
#   'Ranunculus chinensis',
#   'Rhus chinensis',
#   'Rhabdothamnopsis sinensis',
#   'Reticulitermes chinensis',
#   'Rosa chinensis'],
#  'El. japonicus': ['Ephies japonicus',
#   'Echiniscus japonicus',
#   'Epinephelus japonicus',
#   'Eudectus japonicus',
#   'Eupalamus japonicus',
#   'Euscyrtus japonicus',
#   'Eurytetranychoides japonicus',
#   'Echinochasmus japonicus',
#   'Eusphingonotus japonicus',
#   'Elaeocarpus japonicus',
#   'Eodiaptomus japonicus',
#   'Eurypogon japonicus',
#   'Euchiton japonicus',
#   'Eleutherococcus japonicus',
#   'Euonymus japonicus',
#   'Esastigmatobius japonicus',
#   'Eriocheir japonica',
#   'Epiactis japonica',
#   'Elenchus japonicus',
#   'Engraulis japonicus'],
#  'Al. fortunei': ['Ambrostoma fortunei',
#   'Apios fortunei',
#   'Amata fortunei',
#   'Aglaomorpha fortunei',
#   'Alniphyllum fortunei'],
#  'El. chinensis': ['Estigmena chinensis',
#   'Excalfactoria adansonii',
#   'Endothia chinensis',
#   'Eobia chinensis',
#   'Ellobium chinense',
#   'Enithares chinensis',
#   'Eucryptorrhynchus scrobiculatus',
#   'Euops chinensis',
#   'Euagathis chinensis',
#   'Eothenomys wardi',
#   'Eophileurus chinensis',
#   'Elaeocarpus chinensis',
#   'Epicauta chinensis',
#   'Eremurus chinensis',
#   'Eothenomys chinensis',
#   'Epilachna chinensis',
#   'Eptatretus chinensis',
#   'Enkianthus chinensis',
#   'Eurya chinensis',
#   'Eriocheir sinensis',
#   'Excalfactoria chinensis'],
#  'Ma. fordiana': ['Meliphaga fordiana', 'Magnolia fordiana'],
#  'Tr. sebifera': ['Triadica sebifera'],
#  'Me. flexuosa': ['Miltochrista flexuosa',
#   'Menonvillea flexuosa',
#   'Macrozamia flexuosa',
#   'Meliosma flexuosa',
#   'Muhlenbergia flexuosa',
#   'Muhlenbergia multiflora',
#   'Marantochloa flexuosa',
#   'Malcolmia flexuosa',
#   'Mylabris flexuosa',
#   'Marilia flexuosa',
#   'Mauritia flexuosa'],
#  'Ma. grijsii': ['Machilus grijsii'],
#  'Me. azedarach': ['Melia azedarach'],
#  'Qu. phillyreoides': [],
#  'Cu. lanceolata': ['Cleocnemis lanceolata',
#   'Cerastium lanceolatum',
#   'Coelioxys lanceolata',
#   'Coniogramme lanceolata',
#   'Catasticta lanceolata',
#   'Campanula lanceolata',
#   'Cyathula lanceolata',
#   'Ctenitis lanceolata',
#   'Crudia lanceolata',
#   'Claytonia peirsonii',
#   'Chroesthes lanceolata',
#   'Chassalia lanceolata',
#   'Cylindrifflugia lanceolata',
#   'Cylindrocladiella lanceolata',
#   'Cassipourea lanceolata',
#   'Cyanostegia lanceolata',
#   'Calceolaria lanceolata',
#   'Cakile lanceolata',
#   'Cliffortia lanceolata',
#   'Cunninghamia unicanaliculata',
#   'Cephalotaxus lanceolata',
#   'Calyptranthes lanceolata',
#   'Caridina lanceolata',
#   'Claytonia lanceolata',
#   'Chiroxiphia lanceolata',
#   'Camellia lanceolata',
#   'Clusia lanceolata',
#   'Crotalaria lanceolata',
#   'Coreopsis lanceolata',
#   'Canastra lanceolata',
#   'Cotylelobium lanceolatum',
#   'Carex lanceolata',
#   'Codonopsis lanceolata',
#   'Curvibacter lanceolatus',
#   'Crepidiastrum lanceolatum',
#   'Cunninghamia lanceolata',
#   'Callistachys lanceolata',
#   'Cuphea lanceolata'],
#  'Ca. sclerophylla': ['Calamagrostis sclerophylla',
#   'Campanula sclerophylla',
#   'Cousinia sclerophylla',
#   'Castanopsis sclerophylla',
#   'Cryptocarya sclerophylla'],
#  'A.rupestris': ['Aspalathus rupestris',
#   'Agastache rupestris',
#   'Aedes rupestris',
#   'Acanthocarpus rupestris',
#   'Asterolasia rupestris',
#   'Argyrolobium rupestre',
#   'Arundinella rupestris',
#   'Astyanax rupestris',
#   'Asperula rupestris',
#   'Acanthocyclops signifer',
#   'Agrostis rupestris',
#   'Alstroemeria rupestris',
#   'Aloe rupestris',
#   'Amphorocalyx rupestris',
#   'Anthyllis rupestris',
#   'Albuca rupestris',
#   'Anemone rupestris',
#   'Alchemilla rupestris',
#   'Argocoffeopsis rupestris',
#   'Anthracoidea rupestris',
#   'Aosa rupestris',
#   'Adenodolichos rupestris',
#   'Aleisanthia rupestris',
#   'Ambloplites rupestris',
#   'Artemisia rupestris',
#   'Atocion rupestre',
#   'Andreaea rupestris'],
#  'C.anomalum': ['Chlamydomyzium anomalum',
#   'Cardiospermum anomalum',
#   'Campostoma plumbeum',
#   'Campostoma oligolepis',
#   'Campostoma pullum',
#   'Chaetostoma anomalum',
#   'Campostoma anomalum'],
#  'C.commersonii': ['Commicarpus commersonii',
#   'Cephalorhynchus commersonii',
#   'Cylindrocline commersonii',
#   'Catostomus commersonii'],
#  'C.erythrogaster': ['Cephalcia erythrogaster',
#   'Cercopithecus erythrogaster',
#   'Caesio cuning',
#   'Chrosomus erythrogaster'],
#  'C.funduloides': ['Clinostomus funduloides'],
#  'E.caeruleum': ['Entoloma caeruleum',
#   'Exacum caeruleum',
#   'Eryngium caeruleum',
#   'Etheostoma caeruleum'],
#  'N.buccatus': [],
#  'P.notatus': ['Polyipnus notatus',
#   'Platypalpus notatus',
#   'Petaurus notatus',
#   'Peromatus notatus',
#   'Philorhizus notatus',
#   'Platycheirus notatus',
#   'Platynematichthys notatus',
#   'Paraxanthias notatus',
#   'Polemon notatus',
#   'Pissodes notatus',
#   'Pimephales notatus',
#   'Porichthys notatus'],
#  'R.obtusus': ['Rhinichthys obtusus'],
#  'S.atromaculatus': ['Squalidus atromaculatus', 'Semotilus atromaculatus'],
#  'E.blennioides': ['Etheostoma newmanii',
#   'Etheostoma pholidotum',
#   'Etheostoma blennioides'],
#  'E.flabellare': ['Etheostoma humerale', 'Etheostoma flabellare'],
#  'C.cumberlandensis': ['Cambarus cumberlandensis',
#   'Carex cumberlandensis',
#   'Chrosomus cumberlandensis'],
#  'E.kennicotti': ['Etheostoma kennicotti'],
#  'E.nigrum': ['Emoia nigra',
#   'Eiphosoma nigrum',
#   'Empetrum nigrum',
#   'Epicoccum nigrum',
#   'Etheostoma nigrum'],
#  'L.auritus': ['Lepomis auritus',
#   'Lethrinops auritus',
#   'Limnochromis auritus'],
#  'L.macrochirus': ['Lepomis macrochirus'],
#  'R.atratulus': ['Rhinichthys atratulus'],
#  'M.punctulatus': ['Melanoplus punctulatus',
#   'Micropterus henshalli',
#   'Micropterus punctulatus',
#   'Mustelus punctulatus'],
#  'M.erythrurum': ['Moxostoma erythrurum'],
#  'N.leuciodus': ['Notropis leuciodus'],
#  'N.photogenis': ['Notropis scabriceps',
#   'Notropis leuciodus',
#   'Notropis telescopus',
#   'Notropis photogenis',
#   'Notropis ariommus'],
#  'N.miurus': ['Noturus miurus'],
#  'L.aepyptera': ['Lampetra aepyptera'],
#  'L.megalotis': ['Lepomis megalotis'],
#  'L.chrysocephalus': ['Luxilus chrysocephalus'],
#  'N.rubellus': ['Notropis rubellus'],
#  'P.caprodes': ['Percina fulvitaenia', 'Percina burtoni', 'Percina caprodes'],
#  'S.vitreus': ['Syrphoctonus vitreus', 'Sander vitreus'],
#  'A.natalis': ['Amyna natalis', 'Ameiurus natalis'],
#  'N.micropogon': ['Nocomis micropogon'],
#  'E.zonale': ['Etheostoma zonale'],
#  'I.bubalus': ['Ictiobus bubalus'],
#  'L.cyanellus': ['Lepomis cyanellus'],
#  'C.bairdii': ['Centronyx bairdii',
#   'Calliostoma bairdii',
#   'Cryptosoma bairdii',
#   'Calidris bairdii',
#   'Cottus bairdii'],
#  'C.carpio': ['Cyprinus megalophthalmus',
#   'Cyprinus chilia',
#   'Carassioides cantonensis',
#   'Carpiodes carpio',
#   'Cyprinus carpio'],
#  'E.niger': ['Eschatocerus niger',
#   'Ectreposebastes niger',
#   'Epyris niger',
#   'Enoplochiton niger',
#   'Echthrus niger',
#   'Eniclases niger',
#   'Emoia nigra',
#   'Eudactylinodes niger',
#   'Eantis niger',
#   'Epipona niger',
#   'Esox niger',
#   'Eresus cinnaberinus',
#   'Ephedrus niger'],
#  'R.cataractae': ['Rhinichthys cataractae'],
#  'L.cornutus': ['Lithurgus cornutus',
#   'Lissotes cornutus',
#   'Lactoria cornuta',
#   'Larinioides cornutus',
#   'Luxilus cerasinus',
#   'Luxilus cornutus'],
#  'S.trutta': ['Salmo abanticus',
#   'Salmo pellegrini',
#   'Salmo macedonicus',
#   'Salmo labrax',
#   'Salmo caspius',
#   'Salmo letnica',
#   'Symphodus trutta',
#   'Salmo macrostigma',
#   'Salmo marmoratus',
#   'Salmo trutta'],
#  'S.corporalis': ['Semotilus corporalis'],
#  'C.cognatus': ['Cardiophorus cognatus',
#   'Chorthippus fallax',
#   'Corydalus cornutus',
#   'Cybister cognatus',
#   'Cryptoblepharus cognatus',
#   'Cottus cognatus',
#   'Calathus cognatus'],
#  'C.spiloptera': ['Cyprinella spiloptera'],
#  'E.olmstedi': ['Etheostoma olmstedi'],
#  'H.roanokense': ['Hypentelium roanokense'],
#  'S.fontinalis': ['Sabulina fontinalis',
#   'Scirpus fontinalis',
#   'Salvelinus fontinalis']}

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import time

def annotate_cell_with_wikidata(full_name, abbreviation):
    abbreviation = abbreviation.split(".")[0][0] + ". " + abbreviation.split(".")[1].strip()
    
    sparql_endpoint_url = "https://query.wikidata.org/sparql"

    # Step 2: Construct the SPARQL query
    query = """
        SELECT ?entity ?entityLabel ?propertyValue 
        WHERE {{
          # ?entity wdt:P31 wd:Q16521;  
                  wdt:P1813 ?propertyValue;
                  rdfs:label "%s" @en. 
          FILTER (CONTAINS(?propertyValue, "%s"))
          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
        }}
    """ % (full_name, abbreviation)
    
    print(query)


    claims = None

    while claims == None:
        try:
            sparql = SPARQLWrapper(sparql_endpoint_url, agent='example-UA (https://example.com/; mail@example.com)')
            sparql.setQuery(query)
            sparql.setReturnFormat(JSON)
            claims = sparql.query().convert()
            if 'results' not in claims:
                claims = None
        except:
            time.sleep(10)
            continue
    if (len(claims["results"]["bindings"]) > 0):
        return claims["results"]["bindings"][0]["entity"]["value"].replace("http", "https").replace("entity", "wiki")
    return None

# %%
retrieved_annotations = {}
for abbreviation in loaded_data.keys():
    if (abbreviation not in retrieved_annotations.keys()):
        retrieved_annotations[abbreviation] = []
    for full_name in loaded_data[abbreviation]:        
        retrieved_annotation = annotate_cell_with_wikidata(full_name, abbreviation)
        print(retrieved_annotation)
        if (retrieved_annotation != None):
            retrieved_annotations[abbreviation].append(retrieved_annotation)
print(retrieved_annotations)
# Out:
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Diospyros glaucifolia" @en.
#           FILTER (CONTAINS(?propertyValue, "D. glaucifolia"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15245560
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Causonis glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cyanosporus glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Caloncoba glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15390716
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Clematis glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q12841746
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cheilanthes glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15610870
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Caeruleuptychia glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cycas glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q10262621
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Chlorociboria glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q107565987
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Chusquea glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15513414
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cassine glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15313554
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Crotalaria glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15447886
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Choleva glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15736717
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Callitris glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q87597525
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Carinavalva glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15538624
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cliffortia glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q17246272
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cyathea glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q3008072
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cardamine glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15538014
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cleistopholis glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15353329
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Calceolaria glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q13190179
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Chrysiptera glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
# https://www.wikidata.org/wiki/Q1043658
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cheniella glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q42405540
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cladonia glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q3678887
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Canna glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q3318493
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Chrysochlamys glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q5767804
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cyrtostachys glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15466155
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cissus repens" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Craspedia glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15563327
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Citrus glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q50839729
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cyathodes glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q5197638
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Centropodia glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15511993
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cenchrus americanus" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Casuarina glauca" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q2941555
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Capnoides sempervirens" @en.
#           FILTER (CONTAINS(?propertyValue, "C. glauca"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Leiaster glaber" @en.
#           FILTER (CONTAINS(?propertyValue, "L. glaber"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q2540427
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Lotus tenuis" @en.
#           FILTER (CONTAINS(?propertyValue, "L. glaber"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Lithocarpus glaber" @en.
#           FILTER (CONTAINS(?propertyValue, "L. glaber"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q149476
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Quercus serrata" @en.
#           FILTER (CONTAINS(?propertyValue, "Q. serrata"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q847209
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Calamagrostis sclerophylla" @en.
#           FILTER (CONTAINS(?propertyValue, "C. sclerophylla"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15484564
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Campanula sclerophylla" @en.
#           FILTER (CONTAINS(?propertyValue, "C. sclerophylla"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15599065
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cousinia sclerophylla" @en.
#           FILTER (CONTAINS(?propertyValue, "C. sclerophylla"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15561036
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Castanopsis sclerophylla" @en.
#           FILTER (CONTAINS(?propertyValue, "C. sclerophylla"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
# https://www.wikidata.org/wiki/Q15247814
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cryptocarya sclerophylla" @en.
#           FILTER (CONTAINS(?propertyValue, "C. sclerophylla"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15607849
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Lichtwardtia formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q110987123
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Lozotaeniodes formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q2576480
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Liparopsis formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q13492837
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Lactuca formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q24850843
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Lychnuris formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Liparis formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q10956185
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Loligo formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Lithocarpus formosanus" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Liquidambar formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q986006
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Roussoella chinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "R. chinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Rhizochaete chinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "R. chinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Rungia chinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "R. chinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q10872277
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Rubia chinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "R. chinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q10874089
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Riparia chinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "R. chinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Rohdea chinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "R. chinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q93292705
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Ranatra chinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "R. chinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q18382479
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Rhynchospora chinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "R. chinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q5881932
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Ranunculus chinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "R. chinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15235917
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Rhus chinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "R. chinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q163116
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Rhabdothamnopsis sinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "R. chinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Reticulitermes chinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "R. chinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Rosa chinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "R. chinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q344900
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Corydalis fargesii" @en.
#           FILTER (CONTAINS(?propertyValue, "C. fargesii"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q10902884
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Carex fargesii" @en.
#           FILTER (CONTAINS(?propertyValue, "C. fargesii"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q11054923
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Clethra fargesii" @en.
#           FILTER (CONTAINS(?propertyValue, "C. fargesii"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q10929711
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cypripedium fargesii" @en.
#           FILTER (CONTAINS(?propertyValue, "C. fargesii"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q6768588
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Corylus fargesii" @en.
#           FILTER (CONTAINS(?propertyValue, "C. fargesii"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q11076697
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Chengiopanax fargesii" @en.
#           FILTER (CONTAINS(?propertyValue, "C. fargesii"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15551251
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Castanopsis fargesii" @en.
#           FILTER (CONTAINS(?propertyValue, "C. fargesii"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q11110842
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Catalpa fargesii" @en.
#           FILTER (CONTAINS(?propertyValue, "C. fargesii"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15225853
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Castanopsis eyrei" @en.
#           FILTER (CONTAINS(?propertyValue, "C. eyrei"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q10912665
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cyclocodon axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q92351891
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Calamus axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q12702117
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Chartocerus axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q13461889
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cymindis axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q5199558
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cyanotis axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15547426
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cavendishia axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15370697
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Canephora axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q50994923
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Chionanthus axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q110502646
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Campanula axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
# https://www.wikidata.org/wiki/Q15595855
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Crotalaria axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15445350
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Coptosperma supra-axillare" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cyathelia axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q3947845
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Croton axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q3003966
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Caesulia axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15552208
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Choerospondias axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q5103838
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Camarea axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15387013
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Caloglossa axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Clusiella axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15355491
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Coursetia axillaris" @en.
#           FILTER (CONTAINS(?propertyValue, "C. axillaris"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15530224
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Alchornea davidii" @en.
#           FILTER (CONTAINS(?propertyValue, "A. davidii"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q11047764
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Adonis davidii" @en.
#           FILTER (CONTAINS(?propertyValue, "A. davidii"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15363183
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Anemone davidii" @en.
#           FILTER (CONTAINS(?propertyValue, "A. davidii"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15247469
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Adiantum davidii" @en.
#           FILTER (CONTAINS(?propertyValue, "A. davidii"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15249549
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Abraximorpha davidii" @en.
#           FILTER (CONTAINS(?propertyValue, "A. davidii"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q13221459
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Acer davidii" @en.
#           FILTER (CONTAINS(?propertyValue, "A. davidii"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q657935
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Lichtwardtia formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q110987123
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Lozotaeniodes formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q2576480
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Liparopsis formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q13492837
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Lactuca formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
# https://www.wikidata.org/wiki/Q24850843
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Lychnuris formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Liparis formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q10956185
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Loligo formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Lithocarpus formosanus" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Liquidambar formosana" @en.
#           FILTER (CONTAINS(?propertyValue, "L. formosana"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q986006
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cinnamomum camphora" @en.
#           FILTER (CONTAINS(?propertyValue, "C. camphora"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q158722
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Trapa cochinchinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "T. cochinchinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q111436245
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Turpinia cochinchinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "T. cochinchinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15056421
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Triadica cochinchinensis" @en.
#           FILTER (CONTAINS(?propertyValue, "T. cochinchinensis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q15381277
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Spiraea brumalis" @en.
#           FILTER (CONTAINS(?propertyValue, "S. superba"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Siproeta superba" @en.
#           FILTER (CONTAINS(?propertyValue, "S. superba"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Sphaerostephanos superbus" @en.
#           FILTER (CONTAINS(?propertyValue, "S. superba"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Sarada superba" @en.
#           FILTER (CONTAINS(?propertyValue, "S. superba"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q25388852
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Selaginella superba" @en.
#           FILTER (CONTAINS(?propertyValue, "S. superba"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q17256919
#
# ...
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Lithurgus cornutus" @en.
#           FILTER (CONTAINS(?propertyValue, "L. cornutus"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q1966197
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Lissotes cornutus" @en.
#           FILTER (CONTAINS(?propertyValue, "L. cornutus"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Lactoria cornuta" @en.
#           FILTER (CONTAINS(?propertyValue, "L. cornutus"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Larinioides cornutus" @en.
#           FILTER (CONTAINS(?propertyValue, "L. cornutus"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q1302181
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Luxilus cerasinus" @en.
#           FILTER (CONTAINS(?propertyValue, "L. cornutus"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Luxilus cornutus" @en.
#           FILTER (CONTAINS(?propertyValue, "L. cornutus"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Salmo abanticus" @en.
#           FILTER (CONTAINS(?propertyValue, "S. trutta"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Salmo pellegrini" @en.
#           FILTER (CONTAINS(?propertyValue, "S. trutta"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Salmo macedonicus" @en.
#           FILTER (CONTAINS(?propertyValue, "S. trutta"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Salmo labrax" @en.
#           FILTER (CONTAINS(?propertyValue, "S. trutta"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Salmo caspius" @en.
#           FILTER (CONTAINS(?propertyValue, "S. trutta"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Salmo letnica" @en.
#           FILTER (CONTAINS(?propertyValue, "S. trutta"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Symphodus trutta" @en.
#           FILTER (CONTAINS(?propertyValue, "S. trutta"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q28150981
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Salmo macrostigma" @en.
#           FILTER (CONTAINS(?propertyValue, "S. trutta"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Salmo marmoratus" @en.
#           FILTER (CONTAINS(?propertyValue, "S. trutta"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Salmo trutta" @en.
#           FILTER (CONTAINS(?propertyValue, "S. trutta"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q2857311
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Semotilus corporalis" @en.
#           FILTER (CONTAINS(?propertyValue, "S. corporalis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cardiophorus cognatus" @en.
#           FILTER (CONTAINS(?propertyValue, "C. cognatus"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Chorthippus fallax" @en.
#           FILTER (CONTAINS(?propertyValue, "C. cognatus"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Corydalus cornutus" @en.
#           FILTER (CONTAINS(?propertyValue, "C. cognatus"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cybister cognatus" @en.
#           FILTER (CONTAINS(?propertyValue, "C. cognatus"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q2443326
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cryptoblepharus cognatus" @en.
#           FILTER (CONTAINS(?propertyValue, "C. cognatus"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q3005787
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cottus cognatus" @en.
#           FILTER (CONTAINS(?propertyValue, "C. cognatus"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# None
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Calathus cognatus" @en.
#           FILTER (CONTAINS(?propertyValue, "C. cognatus"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q13448286
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Cyprinella spiloptera" @en.
#           FILTER (CONTAINS(?propertyValue, "C. spiloptera"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q3766704
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Etheostoma olmstedi" @en.
#           FILTER (CONTAINS(?propertyValue, "E. olmstedi"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q606436
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Hypentelium roanokense" @en.
#           FILTER (CONTAINS(?propertyValue, "H. roanokense"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q6406968
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Sabulina fontinalis" @en.
#           FILTER (CONTAINS(?propertyValue, "S. fontinalis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q91468425
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Scirpus fontinalis" @en.
#           FILTER (CONTAINS(?propertyValue, "S. fontinalis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
#
# https://www.wikidata.org/wiki/Q49441456
#
#         SELECT ?entity ?entityLabel ?propertyValue
#         WHERE {{
#           ?entity wdt:P31 wd:Q16521;
#                   wdt:P1813 ?propertyValue;
#                   rdfs:label "Salvelinus fontinalis" @en.
#           FILTER (CONTAINS(?propertyValue, "S. fontinalis"))
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
#         }}
# None
# {'D.glaucifolia': ['https://www.wikidata.org/wiki/Q15245560'], 'C.glauca': ['https://www.wikidata.org/wiki/Q15390716', 'https://www.wikidata.org/wiki/Q12841746', 'https://www.wikidata.org/wiki/Q15610870', 'https://www.wikidata.org/wiki/Q10262621', 'https://www.wikidata.org/wiki/Q107565987', 'https://www.wikidata.org/wiki/Q15513414', 'https://www.wikidata.org/wiki/Q15313554', 'https://www.wikidata.org/wiki/Q15447886', 'https://www.wikidata.org/wiki/Q15736717', 'https://www.wikidata.org/wiki/Q87597525', 'https://www.wikidata.org/wiki/Q15538624', 'https://www.wikidata.org/wiki/Q17246272', 'https://www.wikidata.org/wiki/Q3008072', 'https://www.wikidata.org/wiki/Q15538014', 'https://www.wikidata.org/wiki/Q15353329', 'https://www.wikidata.org/wiki/Q13190179', 'https://www.wikidata.org/wiki/Q1043658', 'https://www.wikidata.org/wiki/Q42405540', 'https://www.wikidata.org/wiki/Q3678887', 'https://www.wikidata.org/wiki/Q3318493', 'https://www.wikidata.org/wiki/Q5767804', 'https://www.wikidata.org/wiki/Q15466155', 'https://www.wikidata.org/wiki/Q15563327', 'https://www.wikidata.org/wiki/Q50839729', 'https://www.wikidata.org/wiki/Q5197638', 'https://www.wikidata.org/wiki/Q15511993', 'https://www.wikidata.org/wiki/Q2941555'], 'L.glaber': ['https://www.wikidata.org/wiki/Q2540427', 'https://www.wikidata.org/wiki/Q149476'], 'Q.serrata': ['https://www.wikidata.org/wiki/Q847209'], 'C.sclerophylla': ['https://www.wikidata.org/wiki/Q15484564', 'https://www.wikidata.org/wiki/Q15599065', 'https://www.wikidata.org/wiki/Q15561036', 'https://www.wikidata.org/wiki/Q15247814', 'https://www.wikidata.org/wiki/Q15607849'], 'L.formosana': ['https://www.wikidata.org/wiki/Q110987123', 'https://www.wikidata.org/wiki/Q2576480', 'https://www.wikidata.org/wiki/Q13492837', 'https://www.wikidata.org/wiki/Q24850843', 'https://www.wikidata.org/wiki/Q10956185', 'https://www.wikidata.org/wiki/Q986006'], 'R.chinensis': ['https://www.wikidata.org/wiki/Q10872277', 'https://www.wikidata.org/wiki/Q10874089', 'https://www.wikidata.org/wiki/Q93292705', 'https://www.wikidata.org/wiki/Q18382479', 'https://www.wikidata.org/wiki/Q5881932', 'https://www.wikidata.org/wiki/Q15235917', 'https://www.wikidata.org/wiki/Q163116', 'https://www.wikidata.org/wiki/Q344900'], 'C.fargesii': ['https://www.wikidata.org/wiki/Q10902884', 'https://www.wikidata.org/wiki/Q11054923', 'https://www.wikidata.org/wiki/Q10929711', 'https://www.wikidata.org/wiki/Q6768588', 'https://www.wikidata.org/wiki/Q11076697', 'https://www.wikidata.org/wiki/Q15551251', 'https://www.wikidata.org/wiki/Q11110842', 'https://www.wikidata.org/wiki/Q15225853'], 'Ca. eyrei': ['https://www.wikidata.org/wiki/Q10912665'], 'Ch. axillaris': ['https://www.wikidata.org/wiki/Q92351891', 'https://www.wikidata.org/wiki/Q12702117', 'https://www.wikidata.org/wiki/Q13461889', 'https://www.wikidata.org/wiki/Q5199558', 'https://www.wikidata.org/wiki/Q15547426', 'https://www.wikidata.org/wiki/Q15370697', 'https://www.wikidata.org/wiki/Q50994923', 'https://www.wikidata.org/wiki/Q110502646', 'https://www.wikidata.org/wiki/Q15595855', 'https://www.wikidata.org/wiki/Q15445350', 'https://www.wikidata.org/wiki/Q3947845', 'https://www.wikidata.org/wiki/Q3003966', 'https://www.wikidata.org/wiki/Q15552208', 'https://www.wikidata.org/wiki/Q5103838', 'https://www.wikidata.org/wiki/Q15387013', 'https://www.wikidata.org/wiki/Q15355491', 'https://www.wikidata.org/wiki/Q15530224'], 'Ac. davidii': ['https://www.wikidata.org/wiki/Q11047764', 'https://www.wikidata.org/wiki/Q15363183', 'https://www.wikidata.org/wiki/Q15247469', 'https://www.wikidata.org/wiki/Q15249549', 'https://www.wikidata.org/wiki/Q13221459', 'https://www.wikidata.org/wiki/Q657935'], 'Li. formosana': ['https://www.wikidata.org/wiki/Q110987123', 'https://www.wikidata.org/wiki/Q2576480', 'https://www.wikidata.org/wiki/Q13492837', 'https://www.wikidata.org/wiki/Q24850843', 'https://www.wikidata.org/wiki/Q10956185', 'https://www.wikidata.org/wiki/Q986006'], 'Ci. camphora': ['https://www.wikidata. ...

# %%
for index, row in abbreviation_values.iterrows():
    abbreviation_values.at[index, "Retrieved Annotation"] = retrieved_annotations[row["Cell Value"]]
abbreviation_values.head()
# Out:
#                             Table Name  Column Index  Row Index  \
# 997   34169c088ee848e4866f42e87b4ccbc2             5          1
# 998   34169c088ee848e4866f42e87b4ccbc2             5          5
# 999   34169c088ee848e4866f42e87b4ccbc2             5         11
# 1000  34169c088ee848e4866f42e87b4ccbc2             5         20
# 1001  34169c088ee848e4866f42e87b4ccbc2             5         27
#
#                             Target Annotation  \
# 997   https://www.wikidata.org/wiki/Q15340551
# 998   https://www.wikidata.org/wiki/Q12838227
# 999   https://www.wikidata.org/wiki/Q15490427
# 1000    https://www.wikidata.org/wiki/Q847209
# 1001  https://www.wikidata.org/wiki/Q15247814
#
#                                    Retrieved Annotation      Cell Value
# 997           [https://www.wikidata.org/wiki/Q15245560]   D.glaucifolia
# 998   [https://www.wikidata.org/wiki/Q15390716, http...        C.glauca
# 999   [https://www.wikidata.org/wiki/Q2540427, https...        L.glaber
# 1000            [https://www.wikidata.org/wiki/Q847209]       Q.serrata
# 1001  [https://www.wikidata.org/wiki/Q15484564, http...  C.sclerophylla

# %%
total = 0
for index, row in abbreviation_values.iterrows():
    if row["Target Annotation"] in row["Retrieved Annotation"]:
        total = total + 1
print(total)
# Out:
# 50

# %% [markdown]
# 50 out of 92 are filled with this method

# %%
def list_to_string(my_list):
    # Use join to concatenate the elements of the list into a string with comma separator
    result_string = ','.join(map(str, my_list))
    
    return result_string

abbreviation_values["Retrieved Annotation"] = abbreviation_values["Retrieved Annotation"].apply(lambda value: list_to_string(value))
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
abbreviation_values_retrieved = abbreviation_values[abbreviation_values["Retrieved Annotation"] != ""]

# %%
abbreviation_dict = dict(zip(abbreviation_values_retrieved['Cell Value'], abbreviation_values_retrieved['Retrieved Annotation']))

# %%
abbreviation_dict
# Out:
# {'D.glaucifolia': 'https://www.wikidata.org/wiki/Q15245560',
#  'C.glauca': 'https://www.wikidata.org/wiki/Q15390716,https://www.wikidata.org/wiki/Q12841746,https://www.wikidata.org/wiki/Q15610870,https://www.wikidata.org/wiki/Q10262621,https://www.wikidata.org/wiki/Q107565987,https://www.wikidata.org/wiki/Q15513414,https://www.wikidata.org/wiki/Q15313554,https://www.wikidata.org/wiki/Q15447886,https://www.wikidata.org/wiki/Q15736717,https://www.wikidata.org/wiki/Q87597525,https://www.wikidata.org/wiki/Q15538624,https://www.wikidata.org/wiki/Q17246272,https://www.wikidata.org/wiki/Q3008072,https://www.wikidata.org/wiki/Q15538014,https://www.wikidata.org/wiki/Q15353329,https://www.wikidata.org/wiki/Q13190179,https://www.wikidata.org/wiki/Q1043658,https://www.wikidata.org/wiki/Q42405540,https://www.wikidata.org/wiki/Q3678887,https://www.wikidata.org/wiki/Q3318493,https://www.wikidata.org/wiki/Q5767804,https://www.wikidata.org/wiki/Q15466155,https://www.wikidata.org/wiki/Q15563327,https://www.wikidata.org/wiki/Q50839729,https://www.wikidata.org/wiki/Q5197638,https://www.wikidata.org/wiki/Q15511993,https://www.wikidata.org/wiki/Q2941555',
#  'L.glaber': 'https://www.wikidata.org/wiki/Q2540427,https://www.wikidata.org/wiki/Q149476',
#  'Q.serrata': 'https://www.wikidata.org/wiki/Q847209',
#  'C.sclerophylla': 'https://www.wikidata.org/wiki/Q15484564,https://www.wikidata.org/wiki/Q15599065,https://www.wikidata.org/wiki/Q15561036,https://www.wikidata.org/wiki/Q15247814,https://www.wikidata.org/wiki/Q15607849',
#  'L.formosana': 'https://www.wikidata.org/wiki/Q110987123,https://www.wikidata.org/wiki/Q2576480,https://www.wikidata.org/wiki/Q13492837,https://www.wikidata.org/wiki/Q24850843,https://www.wikidata.org/wiki/Q10956185,https://www.wikidata.org/wiki/Q986006',
#  'R.chinensis': 'https://www.wikidata.org/wiki/Q10872277,https://www.wikidata.org/wiki/Q10874089,https://www.wikidata.org/wiki/Q93292705,https://www.wikidata.org/wiki/Q18382479,https://www.wikidata.org/wiki/Q5881932,https://www.wikidata.org/wiki/Q15235917,https://www.wikidata.org/wiki/Q163116,https://www.wikidata.org/wiki/Q344900',
#  'C.fargesii': 'https://www.wikidata.org/wiki/Q10902884,https://www.wikidata.org/wiki/Q11054923,https://www.wikidata.org/wiki/Q10929711,https://www.wikidata.org/wiki/Q6768588,https://www.wikidata.org/wiki/Q11076697,https://www.wikidata.org/wiki/Q15551251,https://www.wikidata.org/wiki/Q11110842,https://www.wikidata.org/wiki/Q15225853',
#  'Ca. eyrei': 'https://www.wikidata.org/wiki/Q10912665',
#  'Ch. axillaris': 'https://www.wikidata.org/wiki/Q92351891,https://www.wikidata.org/wiki/Q12702117,https://www.wikidata.org/wiki/Q13461889,https://www.wikidata.org/wiki/Q5199558,https://www.wikidata.org/wiki/Q15547426,https://www.wikidata.org/wiki/Q15370697,https://www.wikidata.org/wiki/Q50994923,https://www.wikidata.org/wiki/Q110502646,https://www.wikidata.org/wiki/Q15595855,https://www.wikidata.org/wiki/Q15445350,https://www.wikidata.org/wiki/Q3947845,https://www.wikidata.org/wiki/Q3003966,https://www.wikidata.org/wiki/Q15552208,https://www.wikidata.org/wiki/Q5103838,https://www.wikidata.org/wiki/Q15387013,https://www.wikidata.org/wiki/Q15355491,https://www.wikidata.org/wiki/Q15530224',
#  'Ac. davidii': 'https://www.wikidata.org/wiki/Q11047764,https://www.wikidata.org/wiki/Q15363183,https://www.wikidata.org/wiki/Q15247469,https://www.wikidata.org/wiki/Q15249549,https://www.wikidata.org/wiki/Q13221459,https://www.wikidata.org/wiki/Q657935',
#  'Li. formosana': 'https://www.wikidata.org/wiki/Q110987123,https://www.wikidata.org/wiki/Q2576480,https://www.wikidata.org/wiki/Q13492837,https://www.wikidata.org/wiki/Q24850843,https://www.wikidata.org/wiki/Q10956185,https://www.wikidata.org/wiki/Q986006',
#  'Ci. camphora': 'https://www.wikidata.org/wiki/Q158722',
#  'Tr. cochinchinensis': 'https://www.wikidata.org/wiki/Q111436245,https://www.wikidata.org/wiki/Q15056421,https://www.wikidata.org/wiki/Q15381277',
#  'Sc. superba': 'https://www.wikidata.org/wiki/Q25388852,https://www.wikidata.org/wiki/Q17256919,https://www.wikidata.org/wiki/Q5490808,https://www.wikidata.org/wiki/Q2789327,https://www.wikidata.org/wiki/Q10673900,https://www.wikidata.org/wiki/Q24851461,https://www.wikidata.org/wiki/Q10664695,https://www.wikidata.org/wiki/Q11093140',
#  'Ca. henryi': 'https://www.wikidata.org/wiki/Q10907209,https://www.wikidata.org/wiki/Q10889749,https://www.wikidata.org/wiki/Q10883089,https://www.wikidata.org/wiki/Q111045951,https://www.wikidata.org/wiki/Q11055998,https://www.wikidata.org/wiki/Q10960179,https://www.wikidata.org/wiki/Q14553782,https://www.wikidata.org/wiki/Q5451780,https://www.wikidata.org/wiki/Q10883080,https://www.wikidata.org/wiki/Q1616237,https://www.wikidata.org/wiki/Q10898679,https://www.wikidata.org/wiki/Q4558669,https://www.wikidata.org/wiki/Q577422,https://www.wikidata.org/wiki/Q15230862',
#  'Cy. glauca': 'https://www.wikidata.org/wiki/Q15390716,https://www.wikidata.org/wiki/Q12841746,https://www.wikidata.org/wiki/Q15610870,https://www.wikidata.org/wiki/Q10262621,https://www.wikidata.org/wiki/Q107565987,https://www.wikidata.org/wiki/Q15513414,https://www.wikidata.org/wiki/Q15313554,https://www.wikidata.org/wiki/Q15447886,https://www.wikidata.org/wiki/Q15736717,https://www.wikidata.org/wiki/Q87597525,https://www.wikidata.org/wiki/Q15538624,https://www.wikidata.org/wiki/Q17246272,https://www.wikidata.org/wiki/Q3008072,https://www.wikidata.org/wiki/Q15538014,https://www.wikidata.org/wiki/Q15353329,https://www.wikidata.org/wiki/Q13190179,https://www.wikidata.org/wiki/Q1043658,https://www.wikidata.org/wiki/Q42405540,https://www.wikidata.org/wiki/Q3678887,https://www.wikidata.org/wiki/Q3318493,https://www.wikidata.org/wiki/Q5767804,https://www.wikidata.org/wiki/Q15466155,https://www.wikidata.org/wiki/Q15563327,https://www.wikidata.org/wiki/Q50839729,https://www.wikidata.org/wiki/Q5197638,https://www.wikidata.org/wiki/Q15511993,https://www.wikidata.org/wiki/Q2941555',
#  'Di. japonica': 'https://www.wikidata.org/wiki/Q29867779,https://www.wikidata.org/wiki/Q14471212,https://www.wikidata.org/wiki/Q15340551,https://www.wikidata.org/wiki/Q107627507,https://www.wikidata.org/wiki/Q41297342,https://www.wikidata.org/wiki/Q2189446,https://www.wikidata.org/wiki/Q13510100,https://www.wikidata.org/wiki/Q13492530,https://www.wikidata.org/wiki/Q121304941,https://www.wikidata.org/wiki/Q29533011,https://www.wikidata.org/wiki/Q13849938,https://www.wikidata.org/wiki/Q2183390,https://www.wikidata.org/wiki/Q2436282,https://www.wikidata.org/wiki/Q7779975,https://www.wikidata.org/wiki/Q81852050,https://www.wikidata.org/wiki/Q15464855,https://www.wikidata.org/wiki/Q13596722,https://www.wikidata.org/wiki/Q25842016,https://www.wikidata.org/wiki/Q13590882,https://www.wikidata.org/wiki/Q15584770',
#  'Da. oldhamii': 'https://www.wikidata.org/wiki/Q10887426,https://www.wikidata.org/wiki/Q15248815',
#  'Di. myricoides': 'https://www.wikidata.org/wiki/Q15373466,https://www.wikidata.org/wiki/Q11101598',
#  'Pi. massoniana': 'https://www.wikidata.org/wiki/Q716571',
#  'Ca. fargesii': 'https://www.wikidata.org/wiki/Q10902884,https://www.wikidata.org/wiki/Q11054923,https://www.wikidata.org/wiki/Q10929711,https://www.wikidata.org/wiki/Q6768588,https://www.wikidata.org/wiki/Q11076697,https://www.wikidata.org/wiki/Q15551251,https://www.wikidata.org/wiki/Q11110842,https://www.wikidata.org/wiki/Q15225853',
#  'Ma. thunbergii': 'https://www.wikidata.org/wiki/Q15577918,https://www.wikidata.org/wiki/Q5792073',
#  'It. chinensis': 'https://www.wikidata.org/wiki/Q5792888,https://www.wikidata.org/wiki/Q11180048,https://www.wikidata.org/wiki/Q9010209,https://www.wikidata.org/wiki/Q5710281,https://www.wikidata.org/wiki/Q3156432,https://www.wikidata.org/wiki/Q10905465',
#  'Ko. bipinnata': 'https://www.wikidata.org/wiki/Q2902122',
#  'Ca. carlesii': 'https://www.wikidata.org/wiki/Q15245858',
#  'Qu. serrata': 'https://www.wikidata.org/wiki/Q847209',
#  'Rh. indica': 'https://www.wikidata.org/wiki/Q59599958,https://www.wikidata.org/wiki/Q107100866,https://www.wikidata.org/wiki/Q2109282,https://www.wikidata.org/wiki/Q16991345,https://www.wikidata.org/wiki/Q10648454,https://www.wikidata.org/wiki/Q15535552,https://www.wikidata.org/wiki/Q108323595,https://www.wikidata.org/wiki/Q108326664,https://www.wikidata.org/wiki/Q857650,https://www.wikidata.org/wiki/Q5768150,https://www.wikidata.org/wiki/Q3205640,https://www.wikidata.org/wiki/Q14942201',
#  'Sa. saponaria': 'https://www.wikidata.org/wiki/Q2672802',
#  'Ny. sinensis': 'https://www.wikidata.org/wiki/Q10599801,https://www.wikidata.org/wiki/Q63723403,https://www.wikidata.org/wiki/Q1308236,https://www.wikidata.org/wiki/Q10603162,https://www.wikidata.org/wiki/Q301071,https://www.wikidata.org/wiki/Q7071277,https://www.wikidata.org/wiki/Q10872407,https://www.wikidata.org/wiki/Q108101503,https://www.wikidata.org/wiki/Q881966',
#  'Qu. fabri': 'https://www.wikidata.org/wiki/Q15232490',
#  'Qu. acutissima': 'https://www.wikidata.org/wiki/Q1034859',
#  'Li. glaber': 'https://www.wikidata.org/wiki/Q2540427,https://www.wikidata.org/wiki/Q149476',
#  'Rh. chinensis': 'https://www.wikidata.org/wiki/Q10872277,https://www.wikidata.org/wiki/Q10874089,https://www.wikidata.org/wiki/Q93292705,https://www.wikidata.org/wiki/Q18382479,https://www.wikidata.org/wiki/Q5881932,https://www.wikidata.org/wiki/Q15235917,https://www.wikidata.org/wiki/Q163116,https://www.wikidata.org/wiki/Q344900',
#  'El. japonicus': 'https://www.wikidata.org/wiki/Q14833512,https://www.wikidata.org/wiki/Q4138670,https://www.wikidata.org/wiki/Q116178596,https://www.wikidata.org/wiki/Q2494851,https://www.wikidata.org/wiki/Q7779734,https://www.wikidata.org/wiki/Q11086424,https://www.wikidata.org/wiki/Q10492149,https://www.wikidata.org/wiki/Q11086409,https://www.wikidata.org/wiki/Q13608212,https://www.wikidata.org/wiki/Q2194554,https://www.wikidata.org/wiki/Q15596600,https://www.wikidata.org/wiki/Q15552115,https://www.wikidata.org/wiki/Q161383,https://www.wikidata.org/wiki/Q110532804,https://www.wikidata.org/wiki/Q516676',
#  'Al. fortunei': 'https://www.wikidata.org/wiki/Q10927658,https://www.wikidata.org/wiki/Q4740457,https://www.wikidata.org/wiki/Q66448818,https://www.wikidata.org/wiki/Q15248253',
#  'El. chinensis': 'https://www.wikidata.org/wiki/Q2559084,https://www.wikidata.org/wiki/Q107654496,https://www.wikidata.org/wiki/Q2043147,https://www.wikidata.org/wiki/Q14872350,https://www.wikidata.org/wiki/Q10872313,https://www.wikidata.org/wiki/Q2453984,https://www.wikidata.org/wiki/Q15224985,https://www.wikidata.org/wiki/Q930350,https://www.wikidata.org/wiki/Q1343225,https://www.wikidata.org/wiki/Q8834538',
#  'Ma. fordiana': 'https://www.wikidata.org/wiki/Q2223763,https://www.wikidata.org/wiki/Q10833097',
#  'Tr. sebifera': 'https://www.wikidata.org/wiki/Q702175',
#  'Me. flexuosa': 'https://www.wikidata.org/wiki/Q13533271,https://www.wikidata.org/wiki/Q15547802,https://www.wikidata.org/wiki/Q5472951,https://www.wikidata.org/wiki/Q10928979,https://www.wikidata.org/wiki/Q15516620,https://www.wikidata.org/wiki/Q50844889,https://www.wikidata.org/wiki/Q15546503,https://www.wikidata.org/wiki/Q4446064,https://www.wikidata.org/wiki/Q1875658,https://www.wikidata.org/wiki/Q1016320',
#  'Ma. grijsii': 'https://www.wikidata.org/wiki/Q11178164',
#  'Me. azedarach': 'https://www.wikidata.org/wiki/Q162171',
#  'Cu. lanceolata': 'https://www.wikidata.org/wiki/Q4155340,https://www.wikidata.org/wiki/Q11076743,https://www.wikidata.org/wiki/Q22112229,https://www.wikidata.org/wiki/Q15591682,https://www.wikidata.org/wiki/Q15581309,https://www.wikidata.org/wiki/Q5189858,https://www.wikidata.org/wiki/Q15224834,https://www.wikidata.org/wiki/Q15400824,https://www.wikidata.org/wiki/Q107609817,https://www.wikidata.org/wiki/Q15388894,https://www.wikidata.org/wiki/Q15314009,https://www.wikidata.org/wiki/Q15537974,https://www.wikidata.org/wiki/Q17246207,https://www.wikidata.org/wiki/Q3439066,https://www.wikidata.org/wiki/Q15395432,https://www.wikidata.org/wiki/Q2978738,https://www.wikidata.org/wiki/Q15390194,https://www.wikidata.org/wiki/Q15353587,https://www.wikidata.org/wiki/Q15247527,https://www.wikidata.org/wiki/Q1023836,https://www.wikidata.org/wiki/Q15511898,https://www.wikidata.org/wiki/Q1031585,https://www.wikidata.org/wiki/Q1040125,https://www.wikidata.org/wiki/Q149115,https://www.wikidata.org/wiki/Q5194464',
#  'Ca. sclerophylla': 'https://www.wikidata.org/wiki/Q15484564,https://www.wikidata.org/wiki/Q15599065,https://www.wikidata.org/wiki/Q15561036,https://www.wikidata.org/wiki/Q15247814,https://www.wikidata.org/wiki/Q15607849',
#  'A.rupestris': 'https://www.wikidata.org/wiki/Q15504626,https://www.wikidata.org/wiki/Q4691437,https://www.wikidata.org/wiki/Q14575960,https://www.wikidata.org/wiki/Q15516865,https://www.wikidata.org/wiki/Q15387752,https://www.wikidata.org/wiki/Q11049619,https://www.wikidata.org/wiki/Q15400497,https://www.wikidata.org/wiki/Q6812509,https://www.wikidata.org/wiki/Q15536918,https://www.wikidata.org/wiki/Q309577,https://www.wikidata.org/wiki/Q50987331,https://www.wikidata.org/wiki/Q15524619,https://www.wikidata.org/wiki/Q15517696,https://www.wikidata.org/wiki/Q15228366,https://www.wikidata.org/wiki/Q9598690,https://www.wikidata.org/wiki/Q15397766,https://www.wikidata.org/wiki/Q10413395,https://www.wikidata.org/wiki/Q15321108,https://www.wikidata.org/wiki/Q15522287,https://www.wikidata.org/wiki/Q15395334,https://www.wikidata.org/wiki/Q580679',
#  'C.anomalum': 'https://www.wikidata.org/wiki/Q15546867,https://www.wikidata.org/wiki/Q6431031,https://www.wikidata.org/wiki/Q8261255',
#  'C.commersonii': 'https://www.wikidata.org/wiki/Q55839556,https://www.wikidata.org/wiki/Q5199311',
#  'C.erythrogaster': 'https://www.wikidata.org/wiki/Q14583066',
#  'C.funduloides': 'https://www.wikidata.org/wiki/Q5133901',
#  'E.caeruleum': 'https://www.wikidata.org/wiki/Q10484563,https://www.wikidata.org/wiki/Q5419234,https://www.wikidata.org/wiki/Q17139254',
#  'P.notatus': 'https://www.wikidata.org/wiki/Q106730274,https://www.wikidata.org/wiki/Q14024332,https://www.wikidata.org/wiki/Q102281603,https://www.wikidata.org/wiki/Q14088789,https://www.wikidata.org/wiki/Q49609374,https://www.wikidata.org/wiki/Q27082,https://www.wikidata.org/wiki/Q6498275,https://www.wikidata.org/wiki/Q4425163,https://www.wikidata.org/wiki/Q2006776',
#  'S.atromaculatus': 'https://www.wikidata.org/wiki/Q3761081,https://www.wikidata.org/wiki/Q3133554',
#  'C.cumberlandensis': 'https://www.wikidata.org/wiki/Q15568152',
#  'E.nigrum': 'https://www.wikidata.org/wiki/Q2901994,https://www.wikidata.org/wiki/Q202305,https://www.wikidata.org/wiki/Q5382591',
#  'N.miurus': 'https://www.wikidata.org/wiki/Q3754033',
#  'L.chrysocephalus': 'https://www.wikidata.org/wiki/Q6413408',
#  'P.caprodes': 'https://www.wikidata.org/wiki/Q947772',
#  'S.vitreus': 'https://www.wikidata.org/wiki/Q14515879',
#  'A.natalis': 'https://www.wikidata.org/wiki/Q4749566',
#  'N.micropogon': 'https://www.wikidata.org/wiki/Q6417895',
#  'C.bairdii': 'https://www.wikidata.org/wiki/Q28810889,https://www.wikidata.org/wiki/Q3168812,https://www.wikidata.org/wiki/Q4472379',
#  'E.niger': 'https://www.wikidata.org/wiki/Q110798373,https://www.wikidata.org/wiki/Q2000540,https://www.wikidata.org/wiki/Q3801503,https://www.wikidata.org/wiki/Q2800277,https://www.wikidata.org/wiki/Q28946178,https://www.wikidata.org/wiki/Q4287787,https://www.wikidata.org/wiki/Q14424430,https://www.wikidata.org/wiki/Q93596',
#  'L.cornutus': 'https://www.wikidata.org/wiki/Q1966197,https://www.wikidata.org/wiki/Q1302181',
#  'S.trutta': 'https://www.wikidata.org/wiki/Q28150981,https://www.wikidata.org/wiki/Q2857311',
#  'C.cognatus': 'https://www.wikidata.org/wiki/Q2443326,https://www.wikidata.org/wiki/Q3005787,https://www.wikidata.org/wiki/Q13448286',
#  'C.spiloptera': 'https://www.wikidata.org/wiki/Q3766704',
#  'E.olmstedi': 'https://www.wikidata.org/wiki/Q606436',
#  'H.roanokense': 'https://www.wikidata.org/wiki/Q6406968',
#  'S.fontinalis': 'https://www.wikidata.org/wiki/Q91468425,https://www.wikidata.org/wiki/Q49441456'}

# %%
# Save the dictionary to a Pickle file
import pickle
with open('abbreviation_annotation_mapping.pkl', 'wb') as pickle_file:
    pickle.dump(abbreviation_dict, pickle_file)

# %% [markdown]
# ## Added annotations

# %%
new_column_names = ['Table Name', 'Column Index', 'Row Index', 'Retrieved Annotation']
df_output = pd.read_csv("Dataset/output/cea annotation/cea_biodiv_third_experiment.csv", header=None, names=new_column_names)
df_output.head()
# Out:
#                          Table Name  Column Index  Row Index  \
# 0  008851b16aa04124b3a9195676604f35             0          0
# 1  008851b16aa04124b3a9195676604f35             0          1
# 2  008851b16aa04124b3a9195676604f35             0          2
# 3  008851b16aa04124b3a9195676604f35             0          3
# 4  008851b16aa04124b3a9195676604f35             0          4
#
#                      Retrieved Annotation
# 0     https://www.wikidata.org/wiki/Q7432
# 1  https://www.wikidata.org/wiki/Q2093287
# 2  https://www.wikidata.org/wiki/Q8261255
# 3  https://www.wikidata.org/wiki/Q2942992
# 4  https://www.wikidata.org/wiki/Q1105092

# %%
# join prediction and target dataframes
merged_df = pd.merge(cea_gt, df_output, on=['Table Name', 'Column Index', 'Row Index'])

# %%
# Add Cell Content
def retrieve_cell_value(row):
    df = pd.read_csv(f"Dataset/val/tables/{row['Table Name']}.csv", header=None)
    cell_value = df.iloc[row["Row Index"], row["Column Index"]]
    return cell_value
    
merged_df["Cell Value"] = merged_df.apply(lambda row: retrieve_cell_value(row), axis=1)

# %%
# Count number of nan_values strings with abbreviations
def detect_abbreviation_in_string(row):
    if row["Cell Value"].count(".") == 1 and row["Cell Value"].count("*") == 0 and row["Cell Value"][0].isupper():
        return True
    return False

# Apply the lambda function to identify True values
mask = merged_df[["Cell Value", "Target Annotation"]].apply(lambda row: detect_abbreviation_in_string(row), axis=1)

# Use the mask to filter and store the values that returned True
abbreviation_values_by_google = merged_df.loc[mask, :]
abbreviation_values_by_google
# Out:
#                             Table Name  Column Index  Row Index  \
# 997   34169c088ee848e4866f42e87b4ccbc2             5          1
# 998   34169c088ee848e4866f42e87b4ccbc2             5          5
# 999   34169c088ee848e4866f42e87b4ccbc2             5         11
# 1000  34169c088ee848e4866f42e87b4ccbc2             5         20
# 1001  34169c088ee848e4866f42e87b4ccbc2             5         27
# ...                                ...           ...        ...
# 1431  8249f8533f764f6dbd195a872c18fd6d             0         86
# 1432  8249f8533f764f6dbd195a872c18fd6d             0         87
# 1433  8249f8533f764f6dbd195a872c18fd6d             0         88
# 1434  8249f8533f764f6dbd195a872c18fd6d             0         90
# 1435  8249f8533f764f6dbd195a872c18fd6d             0         91
#
#                             Target Annotation  \
# 997   https://www.wikidata.org/wiki/Q15340551
# 998   https://www.wikidata.org/wiki/Q12838227
# 999   https://www.wikidata.org/wiki/Q15490427
# 1000    https://www.wikidata.org/wiki/Q847209
# 1001  https://www.wikidata.org/wiki/Q15247814
# ...                                       ...
# 1431    https://www.wikidata.org/wiki/Q610177
# 1432   https://www.wikidata.org/wiki/Q3766704
# 1433    https://www.wikidata.org/wiki/Q606436
# 1434   https://www.wikidata.org/wiki/Q6406968
# 1435    https://www.wikidata.org/wiki/Q723654
#
#                          Retrieved Annotation      Cell Value
# 997    https://www.wikidata.org/wiki/Q7687549   D.glaucifolia
# 998    https://www.wikidata.org/wiki/Q2941555        C.glauca
# 999       https://m.wikidata.org/wiki/Q149476        L.glaber
# 1000    https://www.wikidata.org/wiki/Q847209       Q.serrata
# 1001  https://www.wikidata.org/wiki/Q15247814  C.sclerophylla
# ...                                       ...             ...
# 1431    https://www.wikidata.org/wiki/Q649073      C.cognatus
# 1432   https://www.wikidata.org/wiki/Q2320738    C.spiloptera
# 1433    https://www.wikidata.org/wiki/Q606436      E.olmstedi
# 1434   https://www.wikidata.org/wiki/Q6406968    H.roanokense
# 1435  https://www.wikidata.org/wiki/Q91468425    S.fontinalis
#
# [92 rows x 6 columns]

# %%
abbreviation_values_by_google
# Out:
#                             Table Name  Column Index  Row Index  \
# 997   34169c088ee848e4866f42e87b4ccbc2             5          1
# 998   34169c088ee848e4866f42e87b4ccbc2             5          5
# 999   34169c088ee848e4866f42e87b4ccbc2             5         11
# 1000  34169c088ee848e4866f42e87b4ccbc2             5         20
# 1001  34169c088ee848e4866f42e87b4ccbc2             5         27
# ...                                ...           ...        ...
# 1431  8249f8533f764f6dbd195a872c18fd6d             0         86
# 1432  8249f8533f764f6dbd195a872c18fd6d             0         87
# 1433  8249f8533f764f6dbd195a872c18fd6d             0         88
# 1434  8249f8533f764f6dbd195a872c18fd6d             0         90
# 1435  8249f8533f764f6dbd195a872c18fd6d             0         91
#
#                             Target Annotation  \
# 997   https://www.wikidata.org/wiki/Q15340551
# 998   https://www.wikidata.org/wiki/Q12838227
# 999   https://www.wikidata.org/wiki/Q15490427
# 1000    https://www.wikidata.org/wiki/Q847209
# 1001  https://www.wikidata.org/wiki/Q15247814
# ...                                       ...
# 1431    https://www.wikidata.org/wiki/Q610177
# 1432   https://www.wikidata.org/wiki/Q3766704
# 1433    https://www.wikidata.org/wiki/Q606436
# 1434   https://www.wikidata.org/wiki/Q6406968
# 1435    https://www.wikidata.org/wiki/Q723654
#
#                          Retrieved Annotation      Cell Value
# 997    https://www.wikidata.org/wiki/Q7687549   D.glaucifolia
# 998    https://www.wikidata.org/wiki/Q2941555        C.glauca
# 999       https://m.wikidata.org/wiki/Q149476        L.glaber
# 1000    https://www.wikidata.org/wiki/Q847209       Q.serrata
# 1001  https://www.wikidata.org/wiki/Q15247814  C.sclerophylla
# ...                                       ...             ...
# 1431    https://www.wikidata.org/wiki/Q649073      C.cognatus
# 1432   https://www.wikidata.org/wiki/Q2320738    C.spiloptera
# 1433    https://www.wikidata.org/wiki/Q606436      E.olmstedi
# 1434   https://www.wikidata.org/wiki/Q6406968    H.roanokense
# 1435  https://www.wikidata.org/wiki/Q91468425    S.fontinalis
#
# [92 rows x 6 columns]

# %%
abbreviation_values
# Out:
#                             Table Name  Column Index  Row Index  \
# 997   34169c088ee848e4866f42e87b4ccbc2             5          1
# 998   34169c088ee848e4866f42e87b4ccbc2             5          5
# 999   34169c088ee848e4866f42e87b4ccbc2             5         11
# 1000  34169c088ee848e4866f42e87b4ccbc2             5         20
# 1001  34169c088ee848e4866f42e87b4ccbc2             5         27
# ...                                ...           ...        ...
# 1431  8249f8533f764f6dbd195a872c18fd6d             0         86
# 1432  8249f8533f764f6dbd195a872c18fd6d             0         87
# 1433  8249f8533f764f6dbd195a872c18fd6d             0         88
# 1434  8249f8533f764f6dbd195a872c18fd6d             0         90
# 1435  8249f8533f764f6dbd195a872c18fd6d             0         91
#
#                             Target Annotation  \
# 997   https://www.wikidata.org/wiki/Q15340551
# 998   https://www.wikidata.org/wiki/Q12838227
# 999   https://www.wikidata.org/wiki/Q15490427
# 1000    https://www.wikidata.org/wiki/Q847209
# 1001  https://www.wikidata.org/wiki/Q15247814
# ...                                       ...
# 1431    https://www.wikidata.org/wiki/Q610177
# 1432   https://www.wikidata.org/wiki/Q3766704
# 1433    https://www.wikidata.org/wiki/Q606436
# 1434   https://www.wikidata.org/wiki/Q6406968
# 1435    https://www.wikidata.org/wiki/Q723654
#
#                                    Retrieved Annotation      Cell Value
# 997             https://www.wikidata.org/wiki/Q15245560   D.glaucifolia
# 998   https://www.wikidata.org/wiki/Q15390716,https:...        C.glauca
# 999   https://www.wikidata.org/wiki/Q2540427,https:/...        L.glaber
# 1000              https://www.wikidata.org/wiki/Q847209       Q.serrata
# 1001  https://www.wikidata.org/wiki/Q15484564,https:...  C.sclerophylla
# ...                                                 ...             ...
# 1431  https://www.wikidata.org/wiki/Q2443326,https:/...      C.cognatus
# 1432             https://www.wikidata.org/wiki/Q3766704    C.spiloptera
# 1433              https://www.wikidata.org/wiki/Q606436      E.olmstedi
# 1434             https://www.wikidata.org/wiki/Q6406968    H.roanokense
# 1435  https://www.wikidata.org/wiki/Q91468425,https:...    S.fontinalis
#
# [92 rows x 6 columns]

# %%
# Fill NaNs with empty string
abbreviation_values_by_google['Retrieved Annotation'] = abbreviation_values_by_google['Retrieved Annotation'].fillna("")
abbreviation_values_by_google[abbreviation_values_by_google["Retrieved Annotation"] == ""]
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                             Table Name  Column Index  Row Index  \
# 1410  8249f8533f764f6dbd195a872c18fd6d             0         29
# 1412  8249f8533f764f6dbd195a872c18fd6d             0         31
# 1427  8249f8533f764f6dbd195a872c18fd6d             0         78
#
#                            Target Annotation Retrieved Annotation  \
# 1410   https://www.wikidata.org/wiki/Q388110
# 1412  https://www.wikidata.org/wiki/Q3754033
# 1427  https://www.wikidata.org/wiki/Q2178257
#
#         Cell Value
# 1410   N.leuciodus
# 1412      N.miurus
# 1427  R.cataractae

# %%
incorrect_annotations = 511
empty_annotations = 187
correct_annotations = 1311

for (index1, row1), (index2, row2) in zip(abbreviation_values.iterrows(), abbreviation_values_by_google.iterrows()):
    if (row1["Retrieved Annotation"] == ""):
        continue
    if (row1["Target Annotation"] in row1["Retrieved Annotation"]):
        if (row2["Target Annotation"] not in row2["Retrieved Annotation"]):
            if (row2["Retrieved Annotation"] == ""):
                empty_annotations = empty_annotations - 1
            else:
                incorrect_annotations = incorrect_annotations - 1
            correct_annotations = correct_annotations + 1

print(f"Incorrect annotations are {incorrect_annotations}")
print(f"Empty annotations are {empty_annotations}")
print(f"Correct annotations are {correct_annotations}")
# Out:
# Incorrect annotations are 490
# Empty annotations are 186
# Correct annotations are 1333

# %%
precision = correct_annotations / (correct_annotations + incorrect_annotations)

# %%
recall = correct_annotations / (correct_annotations + incorrect_annotations + empty_annotations)

# %%
f1_score = (2 * precision * recall) / (precision + recall)

# %%
f1_score
# Out:
# 0.6957202505219208
